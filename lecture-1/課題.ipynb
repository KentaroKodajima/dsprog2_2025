# %% [markdown]
# # 個人課題1
#
# - Github上でGoogleが管理しているリポジトリの情報をスクレイピングして下記の情報を取得する
#     - リポジトリ名
#     - 主要な言語
#     - スターの数
# - 上記のデータを保存するためのDBを作成し，スクレイピングしたデータを保存する
#     - GithubのAPIは使わないこと（スクレイピングの課題なので）
#     - ちゃんと`time.sleep(1)`入れてね
# - 保存したデータをSELECT文で表示する
# - ソースコードはGithubフローに従って管理すること
#     1. ブランチ作成（add-exercise-1）
#     2. ステージング
#     3. コミット（コミットはキリのいいところでこまめにすること）
#     4. プッシュ
#     5. プルリク
#     6. コードレビュー，マージ（プルリクは自分で処理してよい）
# - GoogleクラスルームでリポジトリURLを提出
# - 提出期限：11月25日（火）23時59分

# %% [markdown]
# ## ----------------------------------------------------------

# %% [markdown]
# ## ライブラリのインポート

# %%
import requests
from bs4 import BeautifulSoup
import sqlite3
import time

# %% [markdown]
# ## SQLiteデータベースの初期化

# %%
# DB接続
conn = sqlite3.connect("google_repos.db")
cur = conn.cursor()

# テーブル作成
cur.execute("""
CREATE TABLE IF NOT EXISTS repos (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT,
    language TEXT,
    stars INTEGER
)
""")
conn.commit()

# %% [markdown]
# ## スクレイピング関数

# %%
BASE_URL = "https://github.com/google?tab=repositories&page="

def scrape_page(page_num):
    url = BASE_URL + str(page_num)
    print(f"Scraping: {url}")
    try:
        res = requests.get(url)
        res.raise_for_status()
        soup = BeautifulSoup(res.text, "html.parser")
        repo_list = soup.find_all("li", class_="Box-row")

        results = []
        for repo in repo_list:
            # リポジトリ名
            name_tag = repo.find("a", itemprop="name codeRepository")
            name = name_tag.text.strip() if name_tag else "Unknown"

            # 言語
            lang_tag = repo.find("span", itemprop="programmingLanguage")
            language = lang_tag.text.strip() if lang_tag else "Unknown"

            # スター数
            star_tag = repo.find("a", href=lambda x: x and "stargazers" in x)
            if star_tag:
                stars_text = star_tag.text.strip().replace(",", "")
                try:
                    stars = int(stars_text)
                except:
                    stars = 0
            else:
                stars = 0

            results.append((name, language, stars))

        return results

    except Exception as e:
        print("Error:", e)
        return []

# %% [markdown]
# ## データ取得 & DB保存

# %%
page = 1
while True:
    repos = scrape_page(page)
    if not repos:  # データが取得できなければ終了
        break

    # DBに保存
    for r in repos:
        cur.execute(
            "INSERT INTO repos (name, language, stars) VALUES (?, ?, ?)",
            (r[0], r[1], r[2])
        )
    conn.commit()

    time.sleep(1)
    page += 1
# Out:
# Scraping: https://github.com/google?tab=repositories&page=1
# Scraping: https://github.com/google?tab=repositories&page=2
# Scraping: https://github.com/google?tab=repositories&page=3
# Scraping: https://github.com/google?tab=repositories&page=4
# Scraping: https://github.com/google?tab=repositories&page=5
# Scraping: https://github.com/google?tab=repositories&page=6
# Scraping: https://github.com/google?tab=repositories&page=7
# Scraping: https://github.com/google?tab=repositories&page=8
# Scraping: https://github.com/google?tab=repositories&page=9
# Scraping: https://github.com/google?tab=repositories&page=10
# Scraping: https://github.com/google?tab=repositories&page=11
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 page = 1
#       2 while True:
# ----> 3     repos = scrape_page(page)
#       4     if not repos:  # データが取得できなければ終了
#       5         break
#
# Cell In[6], line 7, in scrape_page(page_num)
#       5 print(f"Scraping: {url}")
#       6 try:
# ----> 7     res = requests.get(url)
#       8     res.raise_for_status()
#       9     soup = BeautifulSoup(res.text, "html.parser")
#
# File ~/git_practice/dsprog/dsprog2_2025/.venv/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/git_practice/dsprog/dsprog2_2025/.venv/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/git_practice/dsprog/dsprog2_2025/.venv/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/git_practice/dsprog/dsprog2_2025/.venv/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/git_practice/dsprog/dsprog2_2025/.venv/lib/python3.12/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~/git_practice/dsprog/dsprog2_2025/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/git_practice/dsprog/dsprog2_2025/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/git_practice/dsprog/dsprog2_2025/.venv/lib/python3.12/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File ~/.pyenv/versions/3.12.12/lib/python3.12/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File ~/.pyenv/versions/3.12.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/.pyenv/versions/3.12.12/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.12.12/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.12.12/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.12.12/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 保存データの確認

# %%
print("保存済みデータ一覧:")
cur.execute("SELECT id, name, language, stars FROM repos")
for row in cur.fetchall():
    print(row)

conn.close()
# Out:
# 保存済みデータ一覧:
# (1, 'perfetto', 'C++', 5022)
# (2, 'adk-java', 'Java', 973)
# (3, 'ksp', 'Kotlin', 3307)
# (4, 'XNNPACK', 'C', 2181)
# (5, 'koladata', 'C++', 27)
# (6, 'skia-buildbot', 'Go', 158)
# (7, 'merchant-api-samples', 'Java', 10)
# (8, 'xls', 'C++', 1375)
# (9, 'clusterfuzz', 'Python', 5491)
# (10, 'skia', 'C++', 10275)
# (11, 'perfetto', 'C++', 5022)
# (12, 'adk-java', 'Java', 973)
# (13, 'ksp', 'Kotlin', 3307)
# (14, 'XNNPACK', 'C', 2181)
# (15, 'koladata', 'C++', 27)
# (16, 'skia-buildbot', 'Go', 158)
# (17, 'merchant-api-samples', 'Java', 10)
# (18, 'xls', 'C++', 1375)
# (19, 'clusterfuzz', 'Python', 5491)
# (20, 'skia', 'C++', 10275)
# (21, 'perfetto', 'C++', 5022)
# (22, 'adk-java', 'Java', 973)
# (23, 'ksp', 'Kotlin', 3307)
# (24, 'XNNPACK', 'C', 2181)
# (25, 'koladata', 'C++', 27)
# (26, 'skia-buildbot', 'Go', 158)
# (27, 'merchant-api-samples', 'Java', 10)
# (28, 'xls', 'C++', 1375)
# (29, 'clusterfuzz', 'Python', 5491)
# (30, 'skia', 'C++', 10275)
# (31, 'perfetto', 'C++', 5022)
# (32, 'adk-java', 'Java', 973)
# (33, 'ksp', 'Kotlin', 3307)
# (34, 'XNNPACK', 'C', 2181)
# (35, 'koladata', 'C++', 27)
# (36, 'skia-buildbot', 'Go', 158)
# (37, 'merchant-api-samples', 'Java', 10)
# (38, 'xls', 'C++', 1375)
# (39, 'clusterfuzz', 'Python', 5491)
# (40, 'skia', 'C++', 10275)
# (41, 'perfetto', 'C++', 5022)
# (42, 'adk-java', 'Java', 973)
# (43, 'ksp', 'Kotlin', 3307)
# (44, 'XNNPACK', 'C', 2181)
# (45, 'koladata', 'C++', 27)
# (46, 'skia-buildbot', 'Go', 158)
# (47, 'merchant-api-samples', 'Java', 10)
# (48, 'xls', 'C++', 1375)
# (49, 'clusterfuzz', 'Python', 5491)
# (50, 'skia', 'C++', 10275)
# (51, 'perfetto', 'C++', 5022)
# (52, 'adk-java', 'Java', 973)
# (53, 'ksp', 'Kotlin', 3307)
# (54, 'XNNPACK', 'C', 2181)
# (55, 'koladata', 'C++', 27)
# (56, 'skia-buildbot', 'Go', 158)
# (57, 'merchant-api-samples', 'Java', 10)
# (58, 'xls', 'C++', 1375)
# (59, 'clusterfuzz', 'Python', 5491)
# (60, 'skia', 'C++', 10275)
# (61, 'perfetto', 'C++', 5022)
# (62, 'adk-java', 'Java', 973)
# (63, 'ksp', 'Kotlin', 3307)
# (64, 'XNNPACK', 'C', 2181)
# (65, 'koladata', 'C++', 27)
# (66, 'skia-buildbot', 'Go', 158)
# (67, 'merchant-api-samples', 'Java', 10)
# (68, 'xls', 'C++', 1375)
# (69, 'clusterfuzz', 'Python', 5491)
# (70, 'skia', 'C++', 10275)
# (71, 'perfetto', 'C++', 5022)
# (72, 'adk-java', 'Java', 973)
# (73, 'ksp', 'Kotlin', 3307)
# (74, 'XNNPACK', 'C', 2181)
# (75, 'koladata', 'C++', 27)
# (76, 'skia-buildbot', 'Go', 158)
# (77, 'merchant-api-samples', 'Java', 10)
# (78, 'xls', 'C++', 1375)
# (79, 'clusterfuzz', 'Python', 5491)
# (80, 'skia', 'C++', 10275)
# (81, 'perfetto', 'C++', 5022)
# (82, 'adk-java', 'Java', 973)
# (83, 'ksp', 'Kotlin', 3307)
# (84, 'XNNPACK', 'C', 2181)
# (85, 'koladata', 'C++', 27)
# (86, 'skia-buildbot', 'Go', 158)
# (87, 'merchant-api-samples', 'Java', 10)
# (88, 'xls', 'C++', 1375)
# (89, 'clusterfuzz', 'Python', 5491)
# (90, 'skia', 'C++', 10275)
# (91, 'perfetto', 'C++', 5022)
# (92, 'adk-java', 'Java', 973)
# (93, 'ksp', 'Kotlin', 3307)
# (94, 'XNNPACK', 'C', 2181)
# (95, 'koladata', 'C++', 27)
# (96, 'skia-buildbot', 'Go', 158)
# (97, 'merchant-api-samples', 'Java', 10)
# (98, 'xls', 'C++', 1375)
# (99, 'clusterfuzz', 'Python', 5491)
# (100, 'skia', 'C++', 10275)
# (101, 'perfetto', 'C++', 5022)
# (102, 'adk-java', 'Java', 973)
# (103, 'ksp', 'Kotlin', 3307)
# (104, 'XNNPACK', 'C', 2181)
# (105, 'koladata', 'C++', 27)
# (106, 'skia-buildbot', 'Go', 158)
# (107, 'merchant-api-samples', 'Java', 10)
# (108, 'xls', 'C++', 1375)
# (109, 'clusterfuzz', 'Python', 5491)
# (110, 'skia', 'C++', 10275)
# (111, 'perfetto', 'C++', 5022)
# (112, 'adk-java', 'Java', 973)
# (113, 'ksp', 'Kotlin', 3307)
# (114, 'XNNPACK', 'C', 2181)
# (115, 'koladata', 'C++', 27)
# (116, 'skia-buildbot', 'Go', 158)
# (117, 'merchant-api-samples', 'Java', 10)
# (118, 'xls', 'C++', 1375)
# (119, 'clusterfuzz', 'Python', 5491)
# (120, 'skia', 'C++', 10275)
# (121, 'perfetto', 'C++', 5022)
# (122, 'adk-java', 'Java', 973)
# (123, 'ksp', 'Kotlin', 3307)
# (124, 'XNNPACK', 'C', 2181)
# (125, 'koladata', 'C++', 27)
# (126, 'skia-buildbot', 'Go', 158)
# (127, 'merchant-api-samples', 'Java', 10)
# (128, 'xls', 'C++', 1375)
# (129, 'clusterfuzz', 'Python', 5491)
# (130, 'skia', 'C++', 10275)
# (131, 'perfetto', 'C++', 5022)
# (132, 'adk-java', 'Java', 973)
# (133, 'ksp', 'Kotlin', 3307)
# (134, 'XNNPACK', 'C', 2181)
# (135, 'koladata', 'C++', 27)
# (136, 'skia-buildbot', 'Go', 158)
# (137, 'merchant-api-samples', 'Java', 10)
# (138, 'xls', 'C++', 1375)
# (139, 'clusterfuzz', 'Python', 5491)
# (140, 'skia', 'C++', 10275)
# (141, 'perfetto', 'C++', 5022)
# (142, 'adk-java', 'Java', 973)
# (143, 'ksp', 'Kotlin', 3307)
# (144, 'XNNPACK', 'C', 2181)
# (145, 'koladata', 'C++', 27)
# (146, 'skia-buildbot', 'Go', 158)
# (147, 'merchant-api-samples', 'Java', 10)
# (148, 'xls', 'C++', 1375)
# (149, 'clusterfuzz', 'Python', 5491)
# (150, 'skia', 'C++', 10275)
# (151, 'perfetto', 'C++', 5022)
# (152, 'adk-java', 'Java', 973)
# (153, 'ksp', 'Kotlin', 3307)
# (154, 'XNNPACK', 'C', 2181)
# (155, 'koladata', 'C++', 27)
# (156, 'skia-buildbot', 'Go', 158)
# (157, 'merchant-api-samples', 'Java', 10)
# (158, 'xls', 'C++', 1375)
# (159, 'clusterfuzz', 'Python', 5491)
# (160, 'skia', 'C++', 10275)
# (161, 'perfetto', 'C++', 5022)
# (162, 'adk-java', 'Java', 973)
# (163, 'ksp', 'Kotlin', 3307)
# (164, 'XNNPACK', 'C', 2181)
# (165, 'koladata', 'C++', 27)
# (166, 'skia-buildbot', 'Go', 158)
# (167, 'merchant-api-samples', 'Java', 10)
# (168, 'xls', 'C++', 1375)
# (169, 'clusterfuzz', 'Python', 5491)
# (170, 'skia', 'C++', 10275)
# (171, 'perfetto', 'C++', 5022)
# (172, 'adk-java', 'Java', 973)
# (173, 'ksp', 'Kotlin', 3307)
# (174, 'XNNPACK', 'C', 2181)
# (175, 'koladata', 'C++', 27)
# (176, 'skia-buildbot', 'Go', 158)
# (177, 'merchant-api-samples', 'Java', 10)
# (178, 'xls', 'C++', 1375)
# (179, 'clusterfuzz', 'Python', 5491)
# (180, 'skia', 'C++', 10275)
# (181, 'perfetto', 'C++', 5022)
# (182, 'adk-java', 'Java', 973)
# (183, 'ksp', 'Kotlin', 3307)
# (184, 'XNNPACK', 'C', 2181)
# (185, 'koladata', 'C++', 27)
# (186, 'skia-buildbot', 'Go', 158)
# (187, 'merchant-api-samples', 'Java', 10)
# (188, 'xls', 'C++', 1375)
# (189, 'clusterfuzz', 'Python', 5491)
# (190, 'skia', 'C++', 10275)
# (191, 'perfetto', 'C++', 5022)
# (192, 'adk-java', 'Java', 973)
# (193, 'ksp', 'Kotlin', 3307)
# (194, 'XNNPACK', 'C', 2181)
# (195, 'koladata', 'C++', 27)
# (196, 'skia-buildbot', 'Go', 158)
# (197, 'merchant-api-samples', 'Java', 10)
# (198, 'xls', 'C++', 1375)
# (199, 'clusterfuzz', 'Python', 5491)
# (200, 'skia', 'C++', 10275)
# (201, 'perfetto', 'C++', 5022)
# (202, 'adk-java', 'Java', 973)
# (203, 'ksp', 'Kotlin', 3307)
# (204, 'XNNPACK', 'C', 2181)
# (205, 'koladata', 'C++', 27)
# (206, 'skia-buildbot', 'Go', 158)
# (207, 'merchant-api-samples', 'Java', 10)
# (208, 'xls', 'C++', 1375)
# (209, 'clusterfuzz', 'Python', 5491)
# (210, 'skia', 'C++', 10275)
# (211, 'perfetto', 'C++', 5022)
# (212, 'adk-java', 'Java', 973)
# (213, 'ksp', 'Kotlin', 3307)
# (214, 'XNNPACK', 'C', 2181)
# (215, 'koladata', 'C++', 27)
# (216, 'skia-buildbot', 'Go', 158)
# (217, 'merchant-api-samples', 'Java', 10)
# (218, 'xls', 'C++', 1375)
# (219, 'clusterfuzz', 'Python', 5491)
# (220, 'skia', 'C++', 10275)
# (221, 'perfetto', 'C++', 5022)
# (222, 'adk-java', 'Java', 973)
# (223, 'ksp', 'Kotlin', 3307)
# (224, 'XNNPACK', 'C', 2181)
# (225, 'koladata', 'C++', 27)
# (226, 'skia-buildbot', 'Go', 158)
# (227, 'merchant-api-samples', 'Java', 10)
# (228, 'xls', 'C++', 1375)
# (229, 'clusterfuzz', 'Python', 5491)
# (230, 'skia', 'C++', 10275)
# (231, 'perfetto', 'C++', 5022)
# (232, 'adk-java', 'Java', 973)
# (233, 'ksp', 'Kotlin', 3307)
# (234, 'XNNPACK', 'C', 2181)
# (235, 'koladata', 'C++', 27)
# (236, 'skia-buildbot', 'Go', 158)
# (237, 'merchant-api-samples', 'Java', 10)
# (238, 'xls', 'C++', 1375)
# (239, 'clusterfuzz', 'Python', 5491)
# (240, 'skia', 'C++', 10275)
# (241, 'perfetto', 'C++', 5022)
# (242, 'adk-java', 'Java', 973)
# (243, 'ksp', 'Kotlin', 3307)
# (244, 'XNNPACK', 'C', 2181)
# (245, 'koladata', 'C++', 27)
# (246, 'skia-buildbot', 'Go', 158)
# (247, 'merchant-api-samples', 'Java', 10)
# (248, 'xls', 'C++', 1375)
# (249, 'clusterfuzz', 'Python', 5491)
# (250, 'skia', 'C++', 10275)
# (251, 'perfetto', 'C++', 5022)
# (252, 'adk-java', 'Java', 973)
# (253, 'ksp', 'Kotlin', 3307)
# (254, 'XNNPACK', 'C', 2181)
# (255, 'koladata', 'C++', 27)
# (256, 'skia-buildbot', 'Go', 158)
# (257, 'merchant-api-samples', 'Java', 10)
# (258, 'xls', 'C++', 1375)
# (259, 'clusterfuzz', 'Python', 5491)
# (260, 'skia', 'C++', 10275)
# (261, 'perfetto', 'C++', 5022)
# (262, 'adk-java', 'Java', 973)
# (263, 'ksp', 'Kotlin', 3307)
# (264, 'XNNPACK', 'C', 2181)
# (265, 'koladata', 'C++', 27)
# (266, 'skia-buildbot', 'Go', 158)
# (267, 'merchant-api-samples', 'Java', 10)
# (268, 'xls', 'C++', 1375)
# (269, 'clusterfuzz', 'Python', 5491)
# (270, 'skia', 'C++', 10275)
# (271, 'perfetto', 'C++', 5022)
# (272, 'adk-java', 'Java', 973)
# (273, 'ksp', 'Kotlin', 3307)
# (274, 'XNNPACK', 'C', 2181)
# (275, 'koladata', 'C++', 27)
# (276, 'skia-buildbot', 'Go', 158)
# (277, 'merchant-api-samples', 'Java', 10)
# (278, 'xls', 'C++', 1375)
# (279, 'clusterfuzz', 'Python', 5491)
# (280, 'skia', 'C++', 10275)
# (281, 'perfetto', 'C++', 5022)
# (282, 'adk-java', 'Java', 973)
# (283, 'ksp', 'Kotlin', 3307)
# (284, 'XNNPACK', 'C', 2181)
# (285, 'koladata', 'C++', 27)
# (286, 'skia-buildbot', 'Go', 158)
# (287, 'merchant-api-samples', 'Java', 10)
# (288, 'xls', 'C++', 1375)
# (289, 'clusterfuzz', 'Python', 5491)
# (290, 'skia', 'C++', 10275)
# (291, 'perfetto', 'C++', 5022)
# (292, 'adk-java', 'Java', 973)
# (293, 'ksp', 'Kotlin', 3307)
# (294, 'XNNPACK', 'C', 2181)
# (295, 'koladata', 'C++', 27)
# (296, 'skia-buildbot', 'Go', 158)
# (297, 'merchant-api-samples', 'Java', 10)
# (298, 'xls', 'C++', 1375)
# (299, 'clusterfuzz', 'Python', 5491)
# (300, 'skia', 'C++', 10275)
# (301, 'perfetto', 'C++', 5022)
# (302, 'adk-java', 'Java', 973)
# (303, 'ksp', 'Kotlin', 3307)
# (304, 'XNNPACK', 'C', 2181)
# (305, 'koladata', 'C++', 27)
# (306, 'skia-buildbot', 'Go', 158)
# (307, 'merchant-api-samples', 'Java', 10)
# (308, 'xls', 'C++', 1375)
# (309, 'clusterfuzz', 'Python', 5491)
# (310, 'skia', 'C++', 10275)
# (311, 'perfetto', 'C++', 5022)
# (312, 'adk-java', 'Java', 973)
# (313, 'ksp', 'Kotlin', 3307)
# (314, 'XNNPACK', 'C', 2181)
# (315, 'koladata', 'C++', 27)
# (316, 'skia-buildbot', 'Go', 158)
# (317, 'merchant-api-samples', 'Java', 10)
# (318, 'xls', 'C++', 1375)
# (319, 'clusterfuzz', 'Python', 5491)
# (320, 'skia', 'C++', 10275)
# (321, 'perfetto', 'C++', 5022)
# (322, 'adk-java', 'Java', 973)
# (323, 'ksp', 'Kotlin', 3307)
# (324, 'XNNPACK', 'C', 2181)
# (325, 'koladata', 'C++', 27)
# (326, 'skia-buildbot', 'Go', 158)
# (327, 'merchant-api-samples', 'Java', 10)
# (328, 'xls', 'C++', 1375)
# (329, 'clusterfuzz', 'Python', 5491)
# (330, 'skia', 'C++', 10275)
# (331, 'perfetto', 'C++', 5022)
# (332, 'adk-java', 'Java', 973)
# (333, 'ksp', 'Kotlin', 3307)
# (334, 'XNNPACK', 'C', 2181)
# (335, 'koladata', 'C++', 27)
# (336, 'skia-buildbot', 'Go', 158)
# (337, 'merchant-api-samples', 'Java', 10)
# (338, 'xls', 'C++', 1375)
# (339, 'clusterfuzz', 'Python', 5491)
# (340, 'skia', 'C++', 10275)
# (341, 'perfetto', 'C++', 5022)
# (342, 'adk-java', 'Java', 973)
# (343, 'ksp', 'Kotlin', 3307)
# (344, 'XNNPACK', 'C', 2181)
# (345, 'koladata', 'C++', 27)
# (346, 'skia-buildbot', 'Go', 158)
# (347, 'merchant-api-samples', 'Java', 10)
# (348, 'xls', 'C++', 1375)
# (349, 'clusterfuzz', 'Python', 5491)
# (350, 'skia', 'C++', 10275)
# (351, 'perfetto', 'C++', 5022)
# (352, 'adk-java', 'Java', 973)
# (353, 'ksp', 'Kotlin', 3307)
# (354, 'XNNPACK', 'C', 2181)
# (355, 'koladata', 'C++', 27)
# (356, 'skia-buildbot', 'Go', 158)
# (357, 'merchant-api-samples', 'Java', 10)
# (358, 'xls', 'C++', 1375)
# (359, 'clusterfuzz', 'Python', 5491)
# (360, 'skia', 'C++', 10275)
# (361, 'perfetto', 'C++', 5022)
# (362, 'adk-java', 'Java', 973)
# (363, 'ksp', 'Kotlin', 3307)
# (364, 'XNNPACK', 'C', 2181)
# (365, 'koladata', 'C++', 27)
# (366, 'skia-buildbot', 'Go', 158)
# (367, 'merchant-api-samples', 'Java', 10)
# (368, 'xls', 'C++', 1375)
# (369, 'clusterfuzz', 'Python', 5491)
# (370, 'skia', 'C++', 10275)
# (371, 'perfetto', 'C++', 5022)
# (372, 'adk-java', 'Java', 973)
# (373, 'ksp', 'Kotlin', 3307)
# (374, 'XNNPACK', 'C', 2181)
# (375, 'koladata', 'C++', 27)
# (376, 'skia-buildbot', 'Go', 158)
# (377, 'merchant-api-samples', 'Java', 10)
# (378, 'xls', 'C++', 1375)
# (379, 'clusterfuzz', 'Python', 5491)
# (380, 'skia', 'C++', 10275)
# (381, 'perfetto', 'C++', 5022)
# (382, 'adk-java', 'Java', 973)
# (383, 'ksp', 'Kotlin', 3307)
# (384, 'XNNPACK', 'C', 2181)
# (385, 'koladata', 'C++', 27)
# (386, 'skia-buildbot', 'Go', 158)
# (387, 'merchant-api-samples', 'Java', 10)
# (388, 'xls', 'C++', 1375)
# (389, 'clusterfuzz', 'Python', 5491)
# (390, 'skia', 'C++', 10275)
# (391, 'perfetto', 'C++', 5022)
# (392, 'adk-java', 'Java', 973)
# (393, 'ksp', 'Kotlin', 3307)
# (394, 'XNNPACK', 'C', 2181)
# (395, 'koladata', 'C++', 27)
# (396, 'skia-buildbot', 'Go', 158)
# (397, 'merchant-api-samples', 'Java', 10)
# (398, 'xls', 'C++', 1375)
# (399, 'clusterfuzz', 'Python', 5491)
# (400, 'skia', 'C++', 10275)
# (401, 'perfetto', 'C++', 5022)
# (402, 'adk-java', 'Java', 973)
# (403, 'ksp', 'Kotlin', 3307)
# (404, 'XNNPACK', 'C', 2181)
# (405, 'koladata', 'C++', 27)
# (406, 'skia-buildbot', 'Go', 158)
# (407, 'merchant-api-samples', 'Java', 10)
# (408, 'xls', 'C++', 1375)
# (409, 'clusterfuzz', 'Python', 5491)
# (410, 'skia', 'C++', 10275)
# (411, 'perfetto', 'C++', 5022)
# (412, 'adk-java', 'Java', 973)
# (413, 'ksp', 'Kotlin', 3307)
# (414, 'XNNPACK', 'C', 2181)
# (415, 'koladata', 'C++', 27)
# (416, 'skia-buildbot', 'Go', 158)
# (417, 'merchant-api-samples', 'Java', 10)
# (418, 'xls', 'C++', 1375)
# (419, 'clusterfuzz', 'Python', 5491)
# (420, 'skia', 'C++', 10275)
# (421, 'perfetto', 'C++', 5022)
# (422, 'adk-java', 'Java', 973)
# (423, 'ksp', 'Kotlin', 3307)
# (424, 'XNNPACK', 'C', 2181)
# (425, 'koladata', 'C++', 27)
# (426, 'skia-buildbot', 'Go', 158)
# (427, 'merchant-api-samples', 'Java', 10)
# (428, 'xls', 'C++', 1375)
# (429, 'clusterfuzz', 'Python', 5491)
# (430, 'skia', 'C++', 10275)
# (431, 'perfetto', 'C++', 5022)
# (432, 'adk-java', 'Java', 973)
# (433, 'ksp', 'Kotlin', 3307)
# (434, 'XNNPACK', 'C', 2181)
# (435, 'koladata', 'C++', 27)
# (436, 'skia-buildbot', 'Go', 158)
# (437, 'merchant-api-samples', 'Java', 10)
# (438, 'xls', 'C++', 1375)
# (439, 'clusterfuzz', 'Python', 5491)
# (440, 'skia', 'C++', 10275)
# (441, 'perfetto', 'C++', 5022)
# (442, 'adk-java', 'Java', 973)
# (443, 'ksp', 'Kotlin', 3307)
# (444, 'XNNPACK', 'C', 2181)
# (445, 'koladata', 'C++', 27)
# (446, 'skia-buildbot', 'Go', 158)
# (447, 'merchant-api-samples', 'Java', 10)
# (448, 'xls', 'C++', 1375)
# (449, 'clusterfuzz', 'Python', 5491)
# (450, 'skia', 'C++', 10275)
# (451, 'perfetto', 'C++', 5022)
# (452, 'adk-java', 'Java', 973)
# (453, 'ksp', 'Kotlin', 3307)
# (454, 'XNNPACK', 'C', 2181)
# (455, 'koladata', 'C++', 27)
# (456, 'skia-buildbot', 'Go', 158)
# (457, 'merchant-api-samples', 'Java', 10)
# (458, 'xls', 'C++', 1375)
# (459, 'clusterfuzz', 'Python', 5491)
# (460, 'skia', 'C++', 10275)
# (461, 'perfetto', 'C++', 5022)
# (462, 'adk-java', 'Java', 973)
# (463, 'ksp', 'Kotlin', 3307)
# (464, 'XNNPACK', 'C', 2181)
# (465, 'koladata', 'C++', 27)
# (466, 'skia-buildbot', 'Go', 158)
# (467, 'merchant-api-samples', 'Java', 10)
# (468, 'xls', 'C++', 1375)
# (469, 'clusterfuzz', 'Python', 5491)
# (470, 'skia', 'C++', 10275)
# (471, 'perfetto', 'C++', 5022)
# (472, 'adk-java', 'Java', 973)
# (473, 'ksp', 'Kotlin', 3307)
# (474, 'XNNPACK', 'C', 2181)
# (475, 'koladata', 'C++', 27)
# (476, 'skia-buildbot', 'Go', 158)
# (477, 'merchant-api-samples', 'Java', 10)
# (478, 'xls', 'C++', 1375)
# (479, 'clusterfuzz', 'Python', 5491)
# (480, 'skia', 'C++', 10275)
# (481, 'perfetto', 'C++', 5022)
# (482, 'adk-java', 'Java', 973)
# (483, 'ksp', 'Kotlin', 3307)
# (484, 'XNNPACK', 'C', 2181)
# (485, 'koladata', 'C++', 27)
# (486, 'skia-buildbot', 'Go', 158)
# (487, 'merchant-api-samples', 'Java', 10)
# (488, 'xls', 'C++', 1375)
# (489, 'clusterfuzz', 'Python', 5491)
# (490, 'skia', 'C++', 10275)
# (491, 'secure-aggregation', 'Rust', 5)
# (492, 'perfetto', 'C++', 5022)
# (493, 'adk-java', 'Java', 973)
# (494, 'ksp', 'Kotlin', 3307)
# (495, 'XNNPACK', 'C', 2181)
# (496, 'koladata', 'C++', 27)
# (497, 'skia-buildbot', 'Go', 158)
# (498, 'merchant-api-samples', 'Java', 10)
# (499, 'xls', 'C++', 1375)
# (500, 'clusterfuzz', 'Python', 5491)
# (501, 'secure-aggregation', 'Rust', 5)
# (502, 'perfetto', 'C++', 5022)
# (503, 'adk-java', 'Java', 973)
# (504, 'ksp', 'Kotlin', 3307)
# (505, 'XNNPACK', 'C', 2181)
# (506, 'koladata', 'C++', 27)
# (507, 'skia-buildbot', 'Go', 158)
# (508, 'merchant-api-samples', 'Java', 10)
# (509, 'xls', 'C++', 1375)
# (510, 'clusterfuzz', 'Python', 5491)
# (511, 'secure-aggregation', 'Rust', 5)
# (512, 'perfetto', 'C++', 5022)
# (513, 'adk-java', 'Java', 973)
# (514, 'ksp', 'Kotlin', 3307)
# (515, 'XNNPACK', 'C', 2181)
# (516, 'koladata', 'C++', 27)
# (517, 'skia-buildbot', 'Go', 158)
# (518, 'merchant-api-samples', 'Java', 10)
# (519, 'xls', 'C++', 1375)
# (520, 'clusterfuzz', 'Python', 5491)
# (521, 'secure-aggregation', 'Rust', 5)
# (522, 'perfetto', 'C++', 5022)
# (523, 'adk-java', 'Java', 973)
# (524, 'ksp', 'Kotlin', 3307)
# (525, 'XNNPACK', 'C', 2181)
# (526, 'koladata', 'C++', 27)
# (527, 'skia-buildbot', 'Go', 158)
# (528, 'merchant-api-samples', 'Java', 10)
# (529, 'xls', 'C++', 1375)
# (530, 'clusterfuzz', 'Python', 5491)
# (531, 'secure-aggregation', 'Rust', 5)
# (532, 'perfetto', 'C++', 5022)
# (533, 'adk-java', 'Java', 973)
# (534, 'ksp', 'Kotlin', 3307)
# (535, 'XNNPACK', 'C', 2181)
# (536, 'koladata', 'C++', 27)
# (537, 'skia-buildbot', 'Go', 158)
# (538, 'merchant-api-samples', 'Java', 10)
# (539, 'xls', 'C++', 1375)
# (540, 'clusterfuzz', 'Python', 5491)
# (541, 'secure-aggregation', 'Rust', 5)
# (542, 'perfetto', 'C++', 5022)
# (543, 'adk-java', 'Java', 973)
# (544, 'ksp', 'Kotlin', 3307)
# (545, 'XNNPACK', 'C', 2181)
# (546, 'koladata', 'C++', 27)
# (547, 'skia-buildbot', 'Go', 158)
# (548, 'merchant-api-samples', 'Java', 10)
# (549, 'xls', 'C++', 1375)
# (550, 'clusterfuzz', 'Python', 5491)
# (551, 'secure-aggregation', 'Rust', 5)
# (552, 'perfetto', 'C++', 5022)
# (553, 'adk-java', 'Java', 973)
# (554, 'ksp', 'Kotlin', 3307)
# (555, 'XNNPACK', 'C', 2181)
# (556, 'koladata', 'C++', 27)
# (557, 'skia-buildbot', 'Go', 158)
# (558, 'merchant-api-samples', 'Java', 10)
# (559, 'xls', 'C++', 1375)
# (560, 'clusterfuzz', 'Python', 5491)
# (561, 'secure-aggregation', 'Rust', 5)
# (562, 'perfetto', 'C++', 5022)
# (563, 'adk-java', 'Java', 973)
# (564, 'ksp', 'Kotlin', 3307)
# (565, 'XNNPACK', 'C', 2181)
# (566, 'koladata', 'C++', 27)
# (567, 'skia-buildbot', 'Go', 158)
# (568, 'merchant-api-samples', 'Java', 10)
# (569, 'xls', 'C++', 1375)
# (570, 'clusterfuzz', 'Python', 5491)
# (571, 'secure-aggregation', 'Rust', 5)
# (572, 'perfetto', 'C++', 5022)
# (573, 'adk-java', 'Java', 973)
# (574, 'ksp', 'Kotlin', 3307)
# (575, 'XNNPACK', 'C', 2181)
# (576, 'koladata', 'C++', 27)
# (577, 'skia-buildbot', 'Go', 158)
# (578, 'merchant-api-samples', 'Java', 10)
# (579, 'xls', 'C++', 1375)
# (580, 'clusterfuzz', 'Python', 5491)
# (581, 'secure-aggregation', 'Rust', 5)
# (582, 'perfetto', 'C++', 5022)
# (583, 'adk-java', 'Java', 973)
# (584, 'ksp', 'Kotlin', 3307)
# (585, 'XNNPACK', 'C', 2181)
# (586, 'koladata', 'C++', 27)
# (587, 'skia-buildbot', 'Go', 158)
# (588, 'merchant-api-samples', 'Java', 10)
# (589, 'xls', 'C++', 1375)
# (590, 'clusterfuzz', 'Python', 5491)
# (591, 'secure-aggregation', 'Rust', 5)
# (592, 'perfetto', 'C++', 5022)
# (593, 'adk-java', 'Java', 973)
# (594, 'ksp', 'Kotlin', 3307)
# (595, 'XNNPACK', 'C', 2181)
# (596, 'koladata', 'C++', 27)
# (597, 'skia-buildbot', 'Go', 158)
# (598, 'merchant-api-samples', 'Java', 10)
# (599, 'xls', 'C++', 1375)
# (600, 'clusterfuzz', 'Python', 5491)
# (601, 'secure-aggregation', 'Rust', 5)
# (602, 'perfetto', 'C++', 5022)
# (603, 'adk-java', 'Java', 973)
# (604, 'ksp', 'Kotlin', 3307)
# (605, 'XNNPACK', 'C', 2181)
# (606, 'koladata', 'C++', 27)
# (607, 'skia-buildbot', 'Go', 158)
# (608, 'merchant-api-samples', 'Java', 10)
# (609, 'xls', 'C++', 1375)
# (610, 'clusterfuzz', 'Python', 5491)
# (611, 'secure-aggregation', 'Rust', 5)
# (612, 'perfetto', 'C++', 5022)
# (613, 'adk-java', 'Java', 973)
# (614, 'ksp', 'Kotlin', 3307)
# (615, 'XNNPACK', 'C', 2181)
# (616, 'koladata', 'C++', 27)
# (617, 'skia-buildbot', 'Go', 158)
# (618, 'merchant-api-samples', 'Java', 10)
# (619, 'xls', 'C++', 1375)
# (620, 'clusterfuzz', 'Python', 5491)
# (621, 'secure-aggregation', 'Rust', 5)
# (622, 'perfetto', 'C++', 5022)
# (623, 'adk-java', 'Java', 973)
# (624, 'ksp', 'Kotlin', 3307)
# (625, 'XNNPACK', 'C', 2181)
# (626, 'koladata', 'C++', 27)
# (627, 'skia-buildbot', 'Go', 158)
# (628, 'merchant-api-samples', 'Java', 10)
# (629, 'xls', 'C++', 1375)
# (630, 'clusterfuzz', 'Python', 5491)
# (631, 'secure-aggregation', 'Rust', 5)
# (632, 'perfetto', 'C++', 5022)
# (633, 'adk-java', 'Java', 973)
# (634, 'ksp', 'Kotlin', 3307)
# (635, 'XNNPACK', 'C', 2181)
# (636, 'koladata', 'C++', 27)
# (637, 'skia-buildbot', 'Go', 158)
# (638, 'merchant-api-samples', 'Java', 10)
# (639, 'xls', 'C++', 1375)
# (640, 'clusterfuzz', 'Python', 5491)
# (641, 'secure-aggregation', 'Rust', 5)
# (642, 'perfetto', 'C++', 5022)
# (643, 'adk-java', 'Java', 973)
# (644, 'ksp', 'Kotlin', 3307)
# (645, 'XNNPACK', 'C', 2181)
# (646, 'koladata', 'C++', 27)
# (647, 'skia-buildbot', 'Go', 158)
# (648, 'merchant-api-samples', 'Java', 10)
# (649, 'xls', 'C++', 1375)
# (650, 'clusterfuzz', 'Python', 5491)
# (651, 'secure-aggregation', 'Rust', 5)
# (652, 'perfetto', 'C++', 5022)
# (653, 'adk-java', 'Java', 973)
# (654, 'ksp', 'Kotlin', 3307)
# (655, 'XNNPACK', 'C', 2181)
# (656, 'koladata', 'C++', 27)
# (657, 'skia-buildbot', 'Go', 158)
# (658, 'merchant-api-samples', 'Java', 10)
# (659, 'xls', 'C++', 1375)
# (660, 'clusterfuzz', 'Python', 5491)
# (661, 'secure-aggregation', 'Rust', 5)
# (662, 'perfetto', 'C++', 5022)
# (663, 'adk-java', 'Java', 973)
# (664, 'ksp', 'Kotlin', 3307)
# (665, 'XNNPACK', 'C', 2181)
# (666, 'koladata', 'C++', 27)
# (667, 'skia-buildbot', 'Go', 158)
# (668, 'merchant-api-samples', 'Java', 10)
# (669, 'xls', 'C++', 1375)
# (670, 'clusterfuzz', 'Python', 5491)
# (671, 'secure-aggregation', 'Rust', 5)
# (672, 'perfetto', 'C++', 5022)
# (673, 'adk-java', 'Java', 973)
# (674, 'ksp', 'Kotlin', 3307)
# (675, 'XNNPACK', 'C', 2181)
# (676, 'koladata', 'C++', 27)
# (677, 'skia-buildbot', 'Go', 158)
# (678, 'merchant-api-samples', 'Java', 10)
# (679, 'xls', 'C++', 1375)
# (680, 'clusterfuzz', 'Python', 5491)
# (681, 'secure-aggregation', 'Rust', 5)
# (682, 'perfetto', 'C++', 5022)
# (683, 'adk-java', 'Java', 973)
# (684, 'ksp', 'Kotlin', 3307)
# (685, 'XNNPACK', 'C', 2181)
# (686, 'koladata', 'C++', 27)
# (687, 'skia-buildbot', 'Go', 158)
# (688, 'merchant-api-samples', 'Java', 10)
# (689, 'xls', 'C++', 1375)
# (690, 'clusterfuzz', 'Python', 5491)
# (691, 'secure-aggregation', 'Rust', 5)
# (692, 'perfetto', 'C++', 5022)
# (693, 'adk-java', 'Java', 973)
# (694, 'ksp', 'Kotlin', 3307)
# (695, 'XNNPACK', 'C', 2181)
# (696, 'koladata', 'C++', 27)
# (697, 'skia-buildbot', 'Go', 158)
# (698, 'merchant-api-samples', 'Java', 10)
# (699, 'xls', 'C++', 1375)
# (700, 'clusterfuzz', 'Python', 5491)
# (701, 'secure-aggregation', 'Rust', 5)
# (702, 'perfetto', 'C++', 5022)
# (703, 'adk-java', 'Java', 973)
# (704, 'ksp', 'Kotlin', 3307)
# (705, 'XNNPACK', 'C', 2181)
# (706, 'koladata', 'C++', 27)
# (707, 'skia-buildbot', 'Go', 158)
# (708, 'merchant-api-samples', 'Java', 10)
# (709, 'xls', 'C++', 1375)
# (710, 'clusterfuzz', 'Python', 5491)
# (711, 'secure-aggregation', 'Rust', 5)
# (712, 'perfetto', 'C++', 5022)
# (713, 'adk-java', 'Java', 973)
# (714, 'ksp', 'Kotlin', 3307)
# (715, 'XNNPACK', 'C', 2181)
# (716, 'koladata', 'C++', 27)
# (717, 'skia-buildbot', 'Go', 158)
# (718, 'merchant-api-samples', 'Java', 10)
# (719, 'xls', 'C++', 1375)
# (720, 'clusterfuzz', 'Python', 5491)
# (721, 'secure-aggregation', 'Rust', 5)
# (722, 'perfetto', 'C++', 5022)
# (723, 'adk-java', 'Java', 973)
# (724, 'ksp', 'Kotlin', 3307)
# (725, 'XNNPACK', 'C', 2181)
# (726, 'koladata', 'C++', 27)
# (727, 'skia-buildbot', 'Go', 158)
# (728, 'merchant-api-samples', 'Java', 10)
# (729, 'xls', 'C++', 1375)
# (730, 'clusterfuzz', 'Python', 5491)
# (731, 'secure-aggregation', 'Rust', 5)
# (732, 'perfetto', 'C++', 5022)
# (733, 'adk-java', 'Java', 973)
# (734, 'ksp', 'Kotlin', 3307)
# (735, 'XNNPACK', 'C', 2181)
# (736, 'koladata', 'C++', 27)
# (737, 'skia-buildbot', 'Go', 158)
# (738, 'merchant-api-samples', 'Java', 10)
# (739, 'xls', 'C++', 1375)
# (740, 'clusterfuzz', 'Python', 5491)
# (741, 'secure-aggregation', 'Rust', 5)
# (742, 'perfetto', 'C++', 5022)
# (743, 'adk-java', 'Java', 973)
# (744, 'ksp', 'Kotlin', 3307)
# (745, 'XNNPACK', 'C', 2181)
# (746, 'koladata', 'C++', 27)
# (747, 'skia-buildbot', 'Go', 158)
# (748, 'merchant-api-samples', 'Java', 10)
# (749, 'xls', 'C++', 1375)
# (750, 'clusterfuzz', 'Python', 5491)
# (751, 'secure-aggregation', 'Rust', 5)
# (752, 'perfetto', 'C++', 5022)
# (753, 'adk-java', 'Java', 973)
# (754, 'ksp', 'Kotlin', 3307)
# (755, 'XNNPACK', 'C', 2181)
# (756, 'koladata', 'C++', 27)
# (757, 'skia-buildbot', 'Go', 158)
# (758, 'merchant-api-samples', 'Java', 10)
# (759, 'xls', 'C++', 1375)
# (760, 'clusterfuzz', 'Python', 5491)
# (761, 'secure-aggregation', 'Rust', 5)
# (762, 'perfetto', 'C++', 5022)
# (763, 'adk-java', 'Java', 973)
# (764, 'ksp', 'Kotlin', 3307)
# (765, 'XNNPACK', 'C', 2181)
# (766, 'koladata', 'C++', 27)
# (767, 'skia-buildbot', 'Go', 158)
# (768, 'merchant-api-samples', 'Java', 10)
# (769, 'xls', 'C++', 1375)
# (770, 'clusterfuzz', 'Python', 5491)
# (771, 'secure-aggregation', 'Rust', 5)
# (772, 'perfetto', 'C++', 5022)
# (773, 'adk-java', 'Java', 973)
# (774, 'ksp', 'Kotlin', 3307)
# (775, 'XNNPACK', 'C', 2181)
# (776, 'koladata', 'C++', 27)
# (777, 'skia-buildbot', 'Go', 158)
# (778, 'merchant-api-samples', 'Java', 10)
# (779, 'xls', 'C++', 1375)
# (780, 'clusterfuzz', 'Python', 5491)
# (781, 'secure-aggregation', 'Rust', 5)
# (782, 'perfetto', 'C++', 5022)
# (783, 'adk-java', 'Java', 973)
# (784, 'ksp', 'Kotlin', 3307)
# (785, 'XNNPACK', 'C', 2181)
# (786, 'koladata', 'C++', 27)
# (787, 'skia-buildbot', 'Go', 158)
# (788, 'merchant-api-samples', 'Java', 10)
# (789, 'xls', 'C++', 1375)
# (790, 'clusterfuzz', 'Python', 5491)
# (791, 'secure-aggregation', 'Rust', 5)
# (792, 'perfetto', 'C++', 5022)
# (793, 'adk-java', 'Java', 973)
# (794, 'ksp', 'Kotlin', 3307)
# (795, 'XNNPACK', 'C', 2181)
# (796, 'koladata', 'C++', 27)
# (797, 'skia-buildbot', 'Go', 158)
# (798, 'merchant-api-samples', 'Java', 10)
# (799, 'xls', 'C++', 1375)
# (800, 'clusterfuzz', 'Python', 5491)
# (801, 'secure-aggregation', 'Rust', 5)
# (802, 'perfetto', 'C++', 5022)
# (803, 'adk-java', 'Java', 973)
# (804, 'ksp', 'Kotlin', 3307)
# (805, 'XNNPACK', 'C', 2181)
# (806, 'koladata', 'C++', 27)
# (807, 'skia-buildbot', 'Go', 158)
# (808, 'merchant-api-samples', 'Java', 10)
# (809, 'xls', 'C++', 1375)
# (810, 'clusterfuzz', 'Python', 5491)
# (811, 'secure-aggregation', 'Rust', 5)
# (812, 'perfetto', 'C++', 5022)
# (813, 'adk-java', 'Java', 973)
# (814, 'ksp', 'Kotlin', 3307)
# (815, 'XNNPACK', 'C', 2181)
# (816, 'koladata', 'C++', 27)
# (817, 'skia-buildbot', 'Go', 158)
# (818, 'merchant-api-samples', 'Java', 10)
# (819, 'xls', 'C++', 1375)
# (820, 'clusterfuzz', 'Python', 5491)
# (821, 'secure-aggregation', 'Rust', 5)
# (822, 'perfetto', 'C++', 5022)
# (823, 'adk-java', 'Java', 973)
# (824, 'ksp', 'Kotlin', 3307)
# (825, 'XNNPACK', 'C', 2181)
# (826, 'koladata', 'C++', 27)
# (827, 'skia-buildbot', 'Go', 158)
# (828, 'merchant-api-samples', 'Java', 10)
# (829, 'xls', 'C++', 1375)
# (830, 'clusterfuzz', 'Python', 5491)
# (831, 'secure-aggregation', 'Rust', 5)
# (832, 'perfetto', 'C++', 5022)
# (833, 'adk-java', 'Java', 973)
# (834, 'ksp', 'Kotlin', 3307)
# (835, 'XNNPACK', 'C', 2181)
# (836, 'koladata', 'C++', 27)
# (837, 'skia-buildbot', 'Go', 158)
# (838, 'merchant-api-samples', 'Java', 10)
# (839, 'xls', 'C++', 1375)
# (840, 'clusterfuzz', 'Python', 5491)
# (841, 'secure-aggregation', 'Rust', 5)
# (842, 'perfetto', 'C++', 5022)
# (843, 'adk-java', 'Java', 973)
# (844, 'ksp', 'Kotlin', 3307)
# (845, 'XNNPACK', 'C', 2181)
# (846, 'koladata', 'C++', 27)
# (847, 'skia-buildbot', 'Go', 158)
# (848, 'merchant-api-samples', 'Java', 10)
# (849, 'xls', 'C++', 1375)
# (850, 'clusterfuzz', 'Python', 5491)
# (851, 'secure-aggregation', 'Rust', 5)
# (852, 'perfetto', 'C++', 5022)
# (853, 'adk-java', 'Java', 973)
# (854, 'ksp', 'Kotlin', 3307)
# (855, 'XNNPACK', 'C', 2181)
# (856, 'koladata', 'C++', 27)
# (857, 'skia-buildbot', 'Go', 158)
# (858, 'merchant-api-samples', 'Java', 10)
# (859, 'xls', 'C++', 1375)
# (860, 'clusterfuzz', 'Python', 5491)
# (861, 'secure-aggregation', 'Rust', 5)
# (862, 'perfetto', 'C++', 5022)
# (863, 'adk-java', 'Java', 973)
# (864, 'ksp', 'Kotlin', 3307)
# (865, 'XNNPACK', 'C', 2181)
# (866, 'koladata', 'C++', 27)
# (867, 'skia-buildbot', 'Go', 158)
# (868, 'merchant-api-samples', 'Java', 10)
# (869, 'xls', 'C++', 1375)
# (870, 'clusterfuzz', 'Python', 5491)
# (871, 'secure-aggregation', 'Rust', 5)
# (872, 'perfetto', 'C++', 5022)
# (873, 'adk-java', 'Java', 973)
# (874, 'ksp', 'Kotlin', 3307)
# (875, 'XNNPACK', 'C', 2181)
# (876, 'koladata', 'C++', 27)
# (877, 'skia-buildbot', 'Go', 158)
# (878, 'merchant-api-samples', 'Java', 10)
# (879, 'xls', 'C++', 1375)
# (880, 'clusterfuzz', 'Python', 5491)
# (881, 'secure-aggregation', 'Rust', 5)
# (882, 'perfetto', 'C++', 5022)
# (883, 'adk-java', 'Java', 973)
# (884, 'ksp', 'Kotlin', 3307)
# (885, 'XNNPACK', 'C', 2181)
# (886, 'koladata', 'C++', 27)
# (887, 'skia-buildbot', 'Go', 158)
# (888, 'merchant-api-samples', 'Java', 10)
# (889, 'xls', 'C++', 1375)
# (890, 'clusterfuzz', 'Python', 5491)
# (891, 'secure-aggregation', 'Rust', 5)
# (892, 'perfetto', 'C++', 5022)
# (893, 'adk-java', 'Java', 973)
# (894, 'ksp', 'Kotlin', 3307)
# (895, 'XNNPACK', 'C', 2181)
# (896, 'koladata', 'C++', 27)
# (897, 'skia-buildbot', 'Go', 158)
# (898, 'merchant-api-samples', 'Java', 10)
# (899, 'xls', 'C++', 1375)
# (900, 'clusterfuzz', 'Python', 5491)
# (901, 'secure-aggregation', 'Rust', 5)
# (902, 'perfetto', 'C++', 5022)
# (903, 'adk-java', 'Java', 973)
# (904, 'ksp', 'Kotlin', 3307)
# (905, 'XNNPACK', 'C', 2181)
# (906, 'koladata', 'C++', 27)
# (907, 'skia-buildbot', 'Go', 158)
# (908, 'merchant-api-samples', 'Java', 10)
# (909, 'xls', 'C++', 1375)
# (910, 'clusterfuzz', 'Python', 5491)
# (911, 'secure-aggregation', 'Rust', 5)
# (912, 'perfetto', 'C++', 5022)
# (913, 'adk-java', 'Java', 973)
# (914, 'ksp', 'Kotlin', 3307)
# (915, 'XNNPACK', 'C', 2181)
# (916, 'koladata', 'C++', 27)
# (917, 'skia-buildbot', 'Go', 158)
# (918, 'merchant-api-samples', 'Java', 10)
# (919, 'xls', 'C++', 1375)
# (920, 'clusterfuzz', 'Python', 5491)
# (921, 'secure-aggregation', 'Rust', 5)
# (922, 'perfetto', 'C++', 5022)
# (923, 'adk-java', 'Java', 973)
# (924, 'ksp', 'Kotlin', 3307)
# (925, 'XNNPACK', 'C', 2181)
# (926, 'koladata', 'C++', 27)
# (927, 'skia-buildbot', 'Go', 158)
# (928, 'merchant-api-samples', 'Java', 10)
# (929, 'xls', 'C++', 1375)
# (930, 'clusterfuzz', 'Python', 5491)
# (931, 'secure-aggregation', 'Rust', 5)
# (932, 'perfetto', 'C++', 5022)
# (933, 'adk-java', 'Java', 973)
# (934, 'ksp', 'Kotlin', 3307)
# (935, 'XNNPACK', 'C', 2181)
# (936, 'koladata', 'C++', 27)
# (937, 'skia-buildbot', 'Go', 158)
# (938, 'merchant-api-samples', 'Java', 10)
# (939, 'xls', 'C++', 1375)
# (940, 'clusterfuzz', 'Python', 5491)
# (941, 'secure-aggregation', 'Rust', 5)
# (942, 'perfetto', 'C++', 5022)
# (943, 'adk-java', 'Java', 973)
# (944, 'ksp', 'Kotlin', 3307)
# (945, 'XNNPACK', 'C', 2181)
# (946, 'koladata', 'C++', 27)
# (947, 'skia-buildbot', 'Go', 158)
# (948, 'merchant-api-samples', 'Java', 10)
# (949, 'xls', 'C++', 1375)
# (950, 'clusterfuzz', 'Python', 5491)
# (951, 'secure-aggregation', 'Rust', 5)
# (952, 'perfetto', 'C++', 5022)
# (953, 'adk-java', 'Java', 973)
# (954, 'ksp', 'Kotlin', 3307)
# (955, 'XNNPACK', 'C', 2181)
# (956, 'koladata', 'C++', 27)
# (957, 'skia-buildbot', 'Go', 158)
# (958, 'merchant-api-samples', 'Java', 10)
# (959, 'xls', 'C++', 1375)
# (960, 'clusterfuzz', 'Python', 5491)
# (961, 'secure-aggregation', 'Rust', 5)
# (962, 'perfetto', 'C++', 5022)
# (963, 'adk-java', 'Java', 973)
# (964, 'ksp', 'Kotlin', 3307)
# (965, 'XNNPACK', 'C', 2181)
# (966, 'koladata', 'C++', 27)
# (967, 'skia-buildbot', 'Go', 158)
# (968, 'merchant-api-samples', 'Java', 10)
# (969, 'xls', 'C++', 1375)
# (970, 'clusterfuzz', 'Python', 5491)
# (971, 'secure-aggregation', 'Rust', 5)
# (972, 'perfetto', 'C++', 5022)
# (973, 'adk-java', 'Java', 973)
# (974, 'ksp', 'Kotlin', 3307)
# (975, 'XNNPACK', 'C', 2181)
# (976, 'koladata', 'C++', 27)
# (977, 'skia-buildbot', 'Go', 158)
# (978, 'merchant-api-samples', 'Java', 10)
# (979, 'xls', 'C++', 1375)
# (980, 'clusterfuzz', 'Python', 5491)
# (981, 'secure-aggregation', 'Rust', 5)
# (982, 'perfetto', 'C++', 5022)
# (983, 'adk-java', 'Java', 973)
# (984, 'ksp', 'Kotlin', 3307)
# (985, 'XNNPACK', 'C', 2181)
# (986, 'koladata', 'C++', 27)
# (987, 'skia-buildbot', 'Go', 158)
# (988, 'merchant-api-samples', 'Java', 10)
# (989, 'xls', 'C++', 1375)
# (990, 'clusterfuzz', 'Python', 5491)
# (991, 'secure-aggregation', 'Rust', 5)
# (992, 'perfetto', 'C++', 5022)
# (993, 'adk-java', 'Java', 973)
# (994, 'ksp', 'Kotlin', 3307)
# (995, 'XNNPACK', 'C', 2181)
# (996, 'koladata', 'C++', 27)
# (997, 'skia-buildbot', 'Go', 158)
# (998, 'merchant-api-samples', 'Java', 10)
# (999, 'xls', 'C++', 1375)
# (1000, 'clusterfuzz', 'Python', 5491)
# (1001, 'secure-aggregation', 'Rust', 5)
# (1002, 'perfetto', 'C++', 5022)
# (1003, 'adk-java', 'Java', 973)
# (1004, 'ksp', 'Kotlin', 3307)
# (1005, 'XNNPACK', 'C', 2181)
# (1006, 'koladata', 'C++', 27)
# (1007, 'skia-buildbot', 'Go', 158)
# (1008, 'merchant-api-samples', 'Java', 10)
# (1009, 'xls', 'C++', 1375)
# (1010, 'clusterfuzz', 'Python', 5491)
# (1011, 'secure-aggregation', 'Rust', 5)
# (1012, 'perfetto', 'C++', 5022)
# (1013, 'adk-java', 'Java', 973)
# (1014, 'ksp', 'Kotlin', 3307)
# (1015, 'XNNPACK', 'C', 2181)
# (1016, 'koladata', 'C++', 27)
# (1017, 'skia-buildbot', 'Go', 158)
# (1018, 'merchant-api-samples', 'Java', 10)
# (1019, 'xls', 'C++', 1375)
# (1020, 'clusterfuzz', 'Python', 5491)
# (1021, 'secure-aggregation', 'Rust', 5)
# (1022, 'perfetto', 'C++', 5022)
# (1023, 'adk-java', 'Java', 973)
# (1024, 'ksp', 'Kotlin', 3307)
# (1025, 'XNNPACK', 'C', 2181)
# (1026, 'koladata', 'C++', 27)
# (1027, 'skia-buildbot', 'Go', 158)
# (1028, 'merchant-api-samples', 'Java', 10)
# (1029, 'xls', 'C++', 1375)
# (1030, 'clusterfuzz', 'Python', 5491)
# (1031, 'secure-aggregation', 'Rust', 5)
# (1032, 'perfetto', 'C++', 5022)
# (1033, 'adk-java', 'Java', 973)
# (1034, 'ksp', 'Kotlin', 3307)
# (1035, 'XNNPACK', 'C', 2181)
# (1036, 'koladata', 'C++', 27)
# (1037, 'skia-buildbot', 'Go', 158)
# (1038, 'merchant-api-samples', 'Java', 10)
# (1039, 'xls', 'C++', 1375)
# (1040, 'clusterfuzz', 'Python', 5491)
# (1041, 'secure-aggregation', 'Rust', 5)
# (1042, 'perfetto', 'C++', 5022)
# (1043, 'adk-java', 'Java', 973)
# (1044, 'ksp', 'Kotlin', 3307)
# (1045, 'XNNPACK', 'C', 2181)
# (1046, 'koladata', 'C++', 27)
# (1047, 'skia-buildbot', 'Go', 158)
# (1048, 'merchant-api-samples', 'Java', 10)
# (1049, 'xls', 'C++', 1375)
# (1050, 'clusterfuzz', 'Python', 5491)
# (1051, 'secure-aggregation', 'Rust', 5)
# (1052, 'perfetto', 'C++', 5022)
# (1053, 'adk-java', 'Java', 973)
# (1054, 'ksp', 'Kotlin', 3307)
# (1055, 'XNNPACK', 'C', 2181)
# (1056, 'koladata', 'C++', 27)
# (1057, 'skia-buildbot', 'Go', 158)
# (1058, 'merchant-api-samples', 'Java', 10)
# (1059, 'xls', 'C++', 1375)
# (1060, 'clusterfuzz', 'Python', 5491)
# (1061, 'secure-aggregation', 'Rust', 5)
# (1062, 'perfetto', 'C++', 5022)
# (1063, 'adk-java', 'Java', 973)
# (1064, 'ksp', 'Kotlin', 3307)
# (1065, 'XNNPACK', 'C', 2181)
# (1066, 'koladata', 'C++', 27)
# (1067, 'skia-buildbot', 'Go', 158)
# (1068, 'merchant-api-samples', 'Java', 10)
# (1069, 'xls', 'C++', 1375)
# (1070, 'clusterfuzz', 'Python', 5491)
# (1071, 'secure-aggregation', 'Rust', 5)
# (1072, 'perfetto', 'C++', 5022)
# (1073, 'adk-java', 'Java', 973)
# (1074, 'ksp', 'Kotlin', 3307)
# (1075, 'XNNPACK', 'C', 2181)
# (1076, 'koladata', 'C++', 27)
# (1077, 'skia-buildbot', 'Go', 158)
# (1078, 'merchant-api-samples', 'Java', 10)
# (1079, 'xls', 'C++', 1375)
# (1080, 'clusterfuzz', 'Python', 5491)
# (1081, 'secure-aggregation', 'Rust', 5)
# (1082, 'perfetto', 'C++', 5022)
# (1083, 'adk-java', 'Java', 973)
# (1084, 'ksp', 'Kotlin', 3307)
# (1085, 'XNNPACK', 'C', 2181)
# (1086, 'koladata', 'C++', 27)
# (1087, 'skia-buildbot', 'Go', 158)
# (1088, 'merchant-api-samples', 'Java', 10)
# (1089, 'xls', 'C++', 1375)
# (1090, 'clusterfuzz', 'Python', 5491)
# (1091, 'secure-aggregation', 'Rust', 5)
# (1092, 'perfetto', 'C++', 5022)
# (1093, 'adk-java', 'Java', 973)
# (1094, 'ksp', 'Kotlin', 3307)
# (1095, 'XNNPACK', 'C', 2181)
# (1096, 'koladata', 'C++', 27)
# (1097, 'skia-buildbot', 'Go', 158)
# (1098, 'merchant-api-samples', 'Java', 10)
# (1099, 'xls', 'C++', 1375)
# (1100, 'clusterfuzz', 'Python', 5491)
# (1101, 'secure-aggregation', 'Rust', 5)
# (1102, 'perfetto', 'C++', 5022)
# (1103, 'adk-java', 'Java', 973)
# (1104, 'ksp', 'Kotlin', 3307)
# (1105, 'XNNPACK', 'C', 2181)
# (1106, 'koladata', 'C++', 27)
# (1107, 'skia-buildbot', 'Go', 158)
# (1108, 'merchant-api-samples', 'Java', 10)
# (1109, 'xls', 'C++', 1375)
# (1110, 'clusterfuzz', 'Python', 5491)
# (1111, 'secure-aggregation', 'Rust', 5)
# (1112, 'perfetto', 'C++', 5022)
# (1113, 'adk-java', 'Java', 973)
# (1114, 'ksp', 'Kotlin', 3307)
# (1115, 'XNNPACK', 'C', 2181)
# (1116, 'koladata', 'C++', 27)
# (1117, 'skia-buildbot', 'Go', 158)
# (1118, 'merchant-api-samples', 'Java', 10)
# (1119, 'xls', 'C++', 1375)
# (1120, 'clusterfuzz', 'Python', 5491)
# (1121, 'secure-aggregation', 'Rust', 5)
# (1122, 'perfetto', 'C++', 5022)
# (1123, 'adk-java', 'Java', 973)
# (1124, 'ksp', 'Kotlin', 3307)
# (1125, 'XNNPACK', 'C', 2181)
# (1126, 'koladata', 'C++', 27)
# (1127, 'skia-buildbot', 'Go', 158)
# (1128, 'merchant-api-samples', 'Java', 10)
# (1129, 'xls', 'C++', 1375)
# (1130, 'clusterfuzz', 'Python', 5491)
# (1131, 'secure-aggregation', 'Rust', 5)
# (1132, 'perfetto', 'C++', 5022)
# (1133, 'adk-java', 'Java', 973)
# (1134, 'ksp', 'Kotlin', 3307)
# (1135, 'XNNPACK', 'C', 2181)
# (1136, 'koladata', 'C++', 27)
# (1137, 'skia-buildbot', 'Go', 158)
# (1138, 'merchant-api-samples', 'Java', 10)
# (1139, 'xls', 'C++', 1375)
# (1140, 'clusterfuzz', 'Python', 5491)
# (1141, 'secure-aggregation', 'Rust', 5)
# (1142, 'perfetto', 'C++', 5022)
# (1143, 'adk-java', 'Java', 973)
# (1144, 'ksp', 'Kotlin', 3307)
# (1145, 'XNNPACK', 'C', 2181)
# (1146, 'koladata', 'C++', 27)
# (1147, 'skia-buildbot', 'Go', 158)
# (1148, 'merchant-api-samples', 'Java', 10)
# (1149, 'xls', 'C++', 1375)
# (1150, 'clusterfuzz', 'Python', 5491)
# (1151, 'secure-aggregation', 'Rust', 5)
# (1152, 'perfetto', 'C++', 5022)
# (1153, 'adk-java', 'Java', 973)
# (1154, 'ksp', 'Kotlin', 3307)
# (1155, 'XNNPACK', 'C', 2181)
# (1156, 'koladata', 'C++', 27)
# (1157, 'skia-buildbot', 'Go', 158)
# (1158, 'merchant-api-samples', 'Java', 10)
# (1159, 'xls', 'C++', 1375)
# (1160, 'clusterfuzz', 'Python', 5491)
# (1161, 'secure-aggregation', 'Rust', 5)
# (1162, 'perfetto', 'C++', 5022)
# (1163, 'adk-java', 'Java', 973)
# (1164, 'ksp', 'Kotlin', 3307)
# (1165, 'XNNPACK', 'C', 2181)
# (1166, 'koladata', 'C++', 27)
# (1167, 'skia-buildbot', 'Go', 158)
# (1168, 'merchant-api-samples', 'Java', 10)
# (1169, 'xls', 'C++', 1375)
# (1170, 'clusterfuzz', 'Python', 5491)
# (1171, 'secure-aggregation', 'Rust', 5)
# (1172, 'perfetto', 'C++', 5022)
# (1173, 'adk-java', 'Java', 973)
# (1174, 'ksp', 'Kotlin', 3307)
# (1175, 'XNNPACK', 'C', 2181)
# (1176, 'koladata', 'C++', 27)
# (1177, 'skia-buildbot', 'Go', 158)
# (1178, 'merchant-api-samples', 'Java', 10)
# (1179, 'xls', 'C++', 1375)
# (1180, 'clusterfuzz', 'Python', 5491)
# (1181, 'secure-aggregation', 'Rust', 5)
# (1182, 'perfetto', 'C++', 5022)
# (1183, 'adk-java', 'Java', 973)
# (1184, 'ksp', 'Kotlin', 3307)
# (1185, 'XNNPACK', 'C', 2181)
# (1186, 'koladata', 'C++', 27)
# (1187, 'skia-buildbot', 'Go', 158)
# (1188, 'merchant-api-samples', 'Java', 10)
# (1189, 'xls', 'C++', 1375)
# (1190, 'clusterfuzz', 'Python', 5491)
# (1191, 'secure-aggregation', 'Rust', 5)
# (1192, 'perfetto', 'C++', 5022)
# (1193, 'adk-java', 'Java', 973)
# (1194, 'ksp', 'Kotlin', 3307)
# (1195, 'XNNPACK', 'C', 2181)
# (1196, 'koladata', 'C++', 27)
# (1197, 'skia-buildbot', 'Go', 158)
# (1198, 'merchant-api-samples', 'Java', 10)
# (1199, 'xls', 'C++', 1375)
# (1200, 'clusterfuzz', 'Python', 5491)
# (1201, 'secure-aggregation', 'Rust', 5)
# (1202, 'perfetto', 'C++', 5022)
# (1203, 'adk-java', 'Java', 973)
# (1204, 'ksp', 'Kotlin', 3307)
# (1205, 'XNNPACK', 'C', 2181)
# (1206, 'koladata', 'C++', 27)
# (1207, 'skia-buildbot', 'Go', 158)
# (1208, 'merchant-api-samples', 'Java', 10)
# (1209, 'xls', 'C++', 1375)
# (1210, 'clusterfuzz', 'Python', 5491)
# (1211, 'secure-aggregation', 'Rust', 5)
# (1212, 'perfetto', 'C++', 5022)
# (1213, 'adk-java', 'Java', 973)
# (1214, 'ksp', 'Kotlin', 3307)
# (1215, 'XNNPACK', 'C', 2181)
# (1216, 'koladata', 'C++', 27)
# (1217, 'skia-buildbot', 'Go', 158)
# (1218, 'merchant-api-samples', 'Java', 10)
# (1219, 'xls', 'C++', 1375)
# (1220, 'clusterfuzz', 'Python', 5491)
# (1221, 'secure-aggregation', 'Rust', 5)
# (1222, 'perfetto', 'C++', 5022)
# (1223, 'adk-java', 'Java', 973)
# (1224, 'ksp', 'Kotlin', 3307)
# (1225, 'XNNPACK', 'C', 2181)
# (1226, 'koladata', 'C++', 27)
# (1227, 'skia-buildbot', 'Go', 158)
# (1228, 'merchant-api-samples', 'Java', 10)
# (1229, 'xls', 'C++', 1375)
# (1230, 'clusterfuzz', 'Python', 5491)
# (1231, 'secure-aggregation', 'Rust', 5)
# (1232, 'perfetto', 'C++', 5022)
# (1233, 'adk-java', 'Java', 973)
# (1234, 'ksp', 'Kotlin', 3307)
# (1235, 'XNNPACK', 'C', 2181)
# (1236, 'koladata', 'C++', 27)
# (1237, 'skia-buildbot', 'Go', 158)
# (1238, 'merchant-api-samples', 'Java', 10)
# (1239, 'xls', 'C++', 1375)
# (1240, 'clusterfuzz', 'Python', 5491)
# (1241, 'secure-aggregation', 'Rust', 5)
# (1242, 'perfetto', 'C++', 5022)
# (1243, 'adk-java', 'Java', 973)
# (1244, 'ksp', 'Kotlin', 3307)
# (1245, 'XNNPACK', 'C', 2181)
# (1246, 'koladata', 'C++', 27)
# (1247, 'skia-buildbot', 'Go', 158)
# (1248, 'merchant-api-samples', 'Java', 10)
# (1249, 'xls', 'C++', 1375)
# (1250, 'clusterfuzz', 'Python', 5491)
# (1251, 'secure-aggregation', 'Rust', 5)
# (1252, 'perfetto', 'C++', 5022)
# (1253, 'adk-java', 'Java', 973)
# (1254, 'ksp', 'Kotlin', 3307)
# (1255, 'XNNPACK', 'C', 2181)
# (1256, 'koladata', 'C++', 27)
# (1257, 'skia-buildbot', 'Go', 158)
# (1258, 'merchant-api-samples', 'Java', 10)
# (1259, 'xls', 'C++', 1375)
# (1260, 'clusterfuzz', 'Python', 5491)
# (1261, 'secure-aggregation', 'Rust', 5)
# (1262, 'perfetto', 'C++', 5022)
# (1263, 'adk-java', 'Java', 973)
# (1264, 'ksp', 'Kotlin', 3307)
# (1265, 'XNNPACK', 'C', 2181)
# (1266, 'koladata', 'C++', 27)
# (1267, 'skia-buildbot', 'Go', 158)
# (1268, 'merchant-api-samples', 'Java', 10)
# (1269, 'xls', 'C++', 1375)
# (1270, 'clusterfuzz', 'Python', 5491)
# (1271, 'secure-aggregation', 'Rust', 5)
# (1272, 'perfetto', 'C++', 5022)
# (1273, 'adk-java', 'Java', 973)
# (1274, 'ksp', 'Kotlin', 3307)
# (1275, 'XNNPACK', 'C', 2181)
# (1276, 'koladata', 'C++', 27)
# (1277, 'skia-buildbot', 'Go', 158)
# (1278, 'merchant-api-samples', 'Java', 10)
# (1279, 'xls', 'C++', 1375)
# (1280, 'clusterfuzz', 'Python', 5491)
# (1281, 'secure-aggregation', 'Rust', 5)
# (1282, 'perfetto', 'C++', 5022)
# (1283, 'adk-java', 'Java', 973)
# (1284, 'ksp', 'Kotlin', 3307)
# (1285, 'XNNPACK', 'C', 2181)
# (1286, 'koladata', 'C++', 27)
# (1287, 'skia-buildbot', 'Go', 158)
# (1288, 'merchant-api-samples', 'Java', 10)
# (1289, 'xls', 'C++', 1375)
# (1290, 'clusterfuzz', 'Python', 5491)
# (1291, 'secure-aggregation', 'Rust', 5)
# (1292, 'perfetto', 'C++', 5022)
# (1293, 'adk-java', 'Java', 973)
# (1294, 'ksp', 'Kotlin', 3307)
# (1295, 'XNNPACK', 'C', 2181)
# (1296, 'koladata', 'C++', 27)
# (1297, 'skia-buildbot', 'Go', 158)
# (1298, 'merchant-api-samples', 'Java', 10)
# (1299, 'xls', 'C++', 1375)
# (1300, 'clusterfuzz', 'Python', 5491)
# (1301, 'secure-aggregation', 'Rust', 5)
# (1302, 'perfetto', 'C++', 5022)
# (1303, 'adk-java', 'Java', 973)
# (1304, 'ksp', 'Kotlin', 3307)
# (1305, 'XNNPACK', 'C', 2181)
# (1306, 'koladata', 'C++', 27)
# (1307, 'skia-buildbot', 'Go', 158)
# (1308, 'merchant-api-samples', 'Java', 10)
# (1309, 'xls', 'C++', 1375)
# (1310, 'clusterfuzz', 'Python', 5491)
# (1311, 'secure-aggregation', 'Rust', 5)
# (1312, 'perfetto', 'C++', 5022)
# (1313, 'adk-java', 'Java', 973)
# (1314, 'ksp', 'Kotlin', 3307)
# (1315, 'XNNPACK', 'C', 2181)
# (1316, 'koladata', 'C++', 27)
# (1317, 'skia-buildbot', 'Go', 158)
# (1318, 'merchant-api-samples', 'Java', 10)
# (1319, 'xls', 'C++', 1375)
# (1320, 'clusterfuzz', 'Python', 5491)
# (1321, 'secure-aggregation', 'Rust', 5)
# (1322, 'perfetto', 'C++', 5022)
# (1323, 'adk-java', 'Java', 973)
# (1324, 'ksp', 'Kotlin', 3307)
# (1325, 'XNNPACK', 'C', 2181)
# (1326, 'koladata', 'C++', 27)
# (1327, 'skia-buildbot', 'Go', 158)
# (1328, 'merchant-api-samples', 'Java', 10)
# (1329, 'xls', 'C++', 1375)
# (1330, 'clusterfuzz', 'Python', 5491)
# (1331, 'secure-aggregation', 'Rust', 5)
# (1332, 'perfetto', 'C++', 5022)
# (1333, 'adk-java', 'Java', 973)
# (1334, 'ksp', 'Kotlin', 3307)
# (1335, 'XNNPACK', 'C', 2181)
# (1336, 'koladata', 'C++', 27)
# (1337, 'skia-buildbot', 'Go', 158)
# (1338, 'merchant-api-samples', 'Java', 10)
# (1339, 'xls', 'C++', 1375)
# (1340, 'clusterfuzz', 'Python', 5491)
# (1341, 'secure-aggregation', 'Rust', 5)
# (1342, 'perfetto', 'C++', 5022)
# (1343, 'adk-java', 'Java', 973)
# (1344, 'ksp', 'Kotlin', 3307)
# (1345, 'XNNPACK', 'C', 2181)
# (1346, 'koladata', 'C++', 27)
# (1347, 'skia-buildbot', 'Go', 158)
# (1348, 'merchant-api-samples', 'Java', 10)
# (1349, 'xls', 'C++', 1375)
# (1350, 'clusterfuzz', 'Python', 5491)
# (1351, 'secure-aggregation', 'Rust', 5)
# (1352, 'perfetto', 'C++', 5022)
# (1353, 'adk-java', 'Java', 973)
# (1354, 'ksp', 'Kotlin', 3307)
# (1355, 'XNNPACK', 'C', 2181)
# (1356, 'koladata', 'C++', 27)
# (1357, 'skia-buildbot', 'Go', 158)
# (1358, 'merchant-api-samples', 'Java', 10)
# (1359, 'xls', 'C++', 1375)
# (1360, 'clusterfuzz', 'Python', 5491)
# (1361, 'secure-aggregation', 'Rust', 5)
# (1362, 'perfetto', 'C++', 5022)
# (1363, 'adk-java', 'Java', 973)
# (1364, 'ksp', 'Kotlin', 3307)
# (1365, 'XNNPACK', 'C', 2181)
# (1366, 'koladata', 'C++', 27)
# (1367, 'skia-buildbot', 'Go', 158)
# (1368, 'merchant-api-samples', 'Java', 10)
# (1369, 'xls', 'C++', 1375)
# (1370, 'clusterfuzz', 'Python', 5491)
# (1371, 'secure-aggregation', 'Rust', 5)
# (1372, 'perfetto', 'C++', 5022)
# (1373, 'adk-java', 'Java', 973)
# (1374, 'ksp', 'Kotlin', 3307)
# (1375, 'XNNPACK', 'C', 2181)
# (1376, 'koladata', 'C++', 27)
# (1377, 'skia-buildbot', 'Go', 158)
# (1378, 'merchant-api-samples', 'Java', 10)
# (1379, 'xls', 'C++', 1375)
# (1380, 'clusterfuzz', 'Python', 5491)
# (1381, 'secure-aggregation', 'Rust', 5)
# (1382, 'perfetto', 'C++', 5022)
# (1383, 'adk-java', 'Java', 973)
# (1384, 'ksp', 'Kotlin', 3307)
# (1385, 'XNNPACK', 'C', 2181)
# (1386, 'koladata', 'C++', 27)
# (1387, 'skia-buildbot', 'Go', 158)
# (1388, 'merchant-api-samples', 'Java', 10)
# (1389, 'xls', 'C++', 1375)
# (1390, 'clusterfuzz', 'Python', 5491)
# (1391, 'secure-aggregation', 'Rust', 5)
# (1392, 'perfetto', 'C++', 5022)
# (1393, 'adk-java', 'Java', 973)
# (1394, 'ksp', 'Kotlin', 3307)
# (1395, 'XNNPACK', 'C', 2181)
# (1396, 'koladata', 'C++', 27)
# (1397, 'skia-buildbot', 'Go', 158)
# (1398, 'merchant-api-samples', 'Java', 10)
# (1399, 'xls', 'C++', 1375)
# (1400, 'clusterfuzz', 'Python', 5491)
# (1401, 'secure-aggregation', 'Rust', 5)
# (1402, 'perfetto', 'C++', 5022)
# (1403, 'adk-java', 'Java', 973)
# (1404, 'ksp', 'Kotlin', 3307)
# (1405, 'XNNPACK', 'C', 2181)
# (1406, 'koladata', 'C++', 27)
# (1407, 'skia-buildbot', 'Go', 158)
# (1408, 'merchant-api-samples', 'Java', 10)
# (1409, 'xls', 'C++', 1375)
# (1410, 'clusterfuzz', 'Python', 5491)
# (1411, 'secure-aggregation', 'Rust', 5)
# (1412, 'perfetto', 'C++', 5022)
# (1413, 'adk-java', 'Java', 973)
# (1414, 'ksp', 'Kotlin', 3307)
# (1415, 'XNNPACK', 'C', 2181)
# (1416, 'koladata', 'C++', 27)
# (1417, 'skia-buildbot', 'Go', 158)
# (1418, 'merchant-api-samples', 'Java', 10)
# (1419, 'xls', 'C++', 1375)
# (1420, 'clusterfuzz', 'Python', 5491)
# (1421, 'secure-aggregation', 'Rust', 5)
# (1422, 'perfetto', 'C++', 5022)
# (1423, 'adk-java', 'Java', 973)
# (1424, 'ksp', 'Kotlin', 3307)
# (1425, 'XNNPACK', 'C', 2181)
# (1426, 'koladata', 'C++', 27)
# (1427, 'skia-buildbot', 'Go', 158)
# (1428, 'merchant-api-samples', 'Java', 10)
# (1429, 'xls', 'C++', 1375)
# (1430, 'clusterfuzz', 'Python', 5491)
# (1431, 'secure-aggregation', 'Rust', 5)
# (1432, 'perfetto', 'C++', 5022)
# (1433, 'adk-java', 'Java', 973)
# (1434, 'ksp', 'Kotlin', 3307)
# (1435, 'XNNPACK', 'C', 2181)
# (1436, 'koladata', 'C++', 27)
# (1437, 'skia-buildbot', 'Go', 158)
# (1438, 'merchant-api-samples', 'Java', 10)
# (1439, 'xls', 'C++', 1375)
# (1440, 'clusterfuzz', 'Python', 5491)
# (1441, 'secure-aggregation', 'Rust', 5)
# (1442, 'perfetto', 'C++', 5022)
# (1443, 'adk-java', 'Java', 973)
# (1444, 'ksp', 'Kotlin', 3307)
# (1445, 'XNNPACK', 'C', 2181)
# (1446, 'koladata', 'C++', 27)
# (1447, 'skia-buildbot', 'Go', 158)
# (1448, 'merchant-api-samples', 'Java', 10)
# (1449, 'xls', 'C++', 1375)
# (1450, 'clusterfuzz', 'Python', 5491)
# (1451, 'secure-aggregation', 'Rust', 5)
# (1452, 'perfetto', 'C++', 5022)
# (1453, 'adk-java', 'Java', 973)
# (1454, 'ksp', 'Kotlin', 3307)
# (1455, 'XNNPACK', 'C', 2181)
# (1456, 'koladata', 'C++', 27)
# (1457, 'skia-buildbot', 'Go', 158)
# (1458, 'merchant-api-samples', 'Java', 10)
# (1459, 'xls', 'C++', 1375)
# (1460, 'clusterfuzz', 'Python', 5491)
# (1461, 'secure-aggregation', 'Rust', 5)
# (1462, 'perfetto', 'C++', 5022)
# (1463, 'adk-java', 'Java', 973)
# (1464, 'ksp', 'Kotlin', 3307)
# (1465, 'XNNPACK', 'C', 2181)
# (1466, 'koladata', 'C++', 27)
# (1467, 'skia-buildbot', 'Go', 158)
# (1468, 'merchant-api-samples', 'Java', 10)
# (1469, 'xls', 'C++', 1375)
# (1470, 'clusterfuzz', 'Python', 5491)
# (1471, 'secure-aggregation', 'Rust', 5)
# (1472, 'perfetto', 'C++', 5022)
# (1473, 'adk-java', 'Java', 973)
# (1474, 'ksp', 'Kotlin', 3307)
# (1475, 'XNNPACK', 'C', 2181)
# (1476, 'koladata', 'C++', 27)
# (1477, 'skia-buildbot', 'Go', 158)
# ...
# (23790, 'dwh-migration-tools', 'Java', 54)
# (23791, 'dive', 'C++', 17)
# (23792, 'skia-buildbot', 'Go', 158)
# (23793, 'perfetto', 'C++', 5022)
# (23794, 'XNNPACK', 'C', 2181)
# (23795, 'or-tools', 'C++', 12716)
# (23796, 'crubit', 'C++', 924)
# (23797, 'koladata', 'C++', 27)
# (23798, 'heir', 'C++', 610)
# (23799, 'wasefire', 'Rust', 129)
# (23800, 'dwh-migration-tools', 'Java', 54)
# (23801, 'dive', 'C++', 17)
# (23802, 'skia-buildbot', 'Go', 158)
# (23803, 'perfetto', 'C++', 5022)
# (23804, 'XNNPACK', 'C', 2181)
# (23805, 'or-tools', 'C++', 12716)
# (23806, 'crubit', 'C++', 924)
# (23807, 'koladata', 'C++', 27)
# (23808, 'heir', 'C++', 610)
# (23809, 'wasefire', 'Rust', 129)
# (23810, 'dwh-migration-tools', 'Java', 54)
# (23811, 'dive', 'C++', 17)
# (23812, 'skia-buildbot', 'Go', 158)
# (23813, 'perfetto', 'C++', 5022)
# (23814, 'XNNPACK', 'C', 2181)
# (23815, 'or-tools', 'C++', 12716)
# (23816, 'crubit', 'C++', 924)
# (23817, 'koladata', 'C++', 27)
# (23818, 'heir', 'C++', 610)
# (23819, 'wasefire', 'Rust', 129)
# (23820, 'dwh-migration-tools', 'Java', 54)
# (23821, 'dive', 'C++', 17)
# (23822, 'skia-buildbot', 'Go', 158)
# (23823, 'perfetto', 'C++', 5022)
# (23824, 'XNNPACK', 'C', 2181)
# (23825, 'or-tools', 'C++', 12716)
# (23826, 'crubit', 'C++', 924)
# (23827, 'koladata', 'C++', 27)
# (23828, 'heir', 'C++', 610)
# (23829, 'wasefire', 'Rust', 129)
# (23830, 'dwh-migration-tools', 'Java', 54)
# (23831, 'dive', 'C++', 17)
# (23832, 'skia-buildbot', 'Go', 158)
# (23833, 'perfetto', 'C++', 5022)
# (23834, 'XNNPACK', 'C', 2181)
# (23835, 'or-tools', 'C++', 12716)
# (23836, 'crubit', 'C++', 924)
# (23837, 'koladata', 'C++', 27)
# (23838, 'heir', 'C++', 610)
# (23839, 'wasefire', 'Rust', 129)
# (23840, 'dwh-migration-tools', 'Java', 54)
# (23841, 'dive', 'C++', 17)
# (23842, 'skia-buildbot', 'Go', 158)
# (23843, 'perfetto', 'C++', 5022)
# (23844, 'XNNPACK', 'C', 2181)
# (23845, 'or-tools', 'C++', 12716)
# (23846, 'crubit', 'C++', 924)
# (23847, 'koladata', 'C++', 27)
# (23848, 'heir', 'C++', 610)
# (23849, 'wasefire', 'Rust', 129)
# (23850, 'dwh-migration-tools', 'Java', 54)
# (23851, 'dive', 'C++', 17)
# (23852, 'skia-buildbot', 'Go', 158)
# (23853, 'perfetto', 'C++', 5022)
# (23854, 'XNNPACK', 'C', 2181)
# (23855, 'or-tools', 'C++', 12716)
# (23856, 'crubit', 'C++', 924)
# (23857, 'koladata', 'C++', 27)
# (23858, 'heir', 'C++', 610)
# (23859, 'wasefire', 'Rust', 129)
# (23860, 'dwh-migration-tools', 'Java', 54)
# (23861, 'dive', 'C++', 17)
# (23862, 'skia-buildbot', 'Go', 158)
# (23863, 'perfetto', 'C++', 5022)
# (23864, 'XNNPACK', 'C', 2181)
# (23865, 'or-tools', 'C++', 12716)
# (23866, 'crubit', 'C++', 924)
# (23867, 'koladata', 'C++', 27)
# (23868, 'heir', 'C++', 610)
# (23869, 'wasefire', 'Rust', 129)
# (23870, 'dwh-migration-tools', 'Java', 54)
# (23871, 'dive', 'C++', 17)
# (23872, 'skia-buildbot', 'Go', 158)
# (23873, 'perfetto', 'C++', 5022)
# (23874, 'XNNPACK', 'C', 2181)
# (23875, 'or-tools', 'C++', 12716)
# (23876, 'crubit', 'C++', 924)
# (23877, 'koladata', 'C++', 27)
# (23878, 'heir', 'C++', 610)
# (23879, 'wasefire', 'Rust', 129)
# (23880, 'dwh-migration-tools', 'Java', 54)
# (23881, 'dive', 'C++', 17)
# (23882, 'skia-buildbot', 'Go', 158)
# (23883, 'perfetto', 'C++', 5022)
# (23884, 'XNNPACK', 'C', 2181)
# (23885, 'or-tools', 'C++', 12716)
# (23886, 'crubit', 'C++', 924)
# (23887, 'koladata', 'C++', 27)
# (23888, 'heir', 'C++', 610)
# (23889, 'wasefire', 'Rust', 129)
# (23890, 'dwh-migration-tools', 'Java', 54)
# (23891, 'dive', 'C++', 17)
# (23892, 'skia-buildbot', 'Go', 158)
# (23893, 'perfetto', 'C++', 5022)
# (23894, 'XNNPACK', 'C', 2181)
# (23895, 'or-tools', 'C++', 12716)
# (23896, 'crubit', 'C++', 924)
# (23897, 'koladata', 'C++', 27)
# (23898, 'heir', 'C++', 610)
# (23899, 'wasefire', 'Rust', 129)
# (23900, 'dwh-migration-tools', 'Java', 54)
# (23901, 'dive', 'C++', 17)
# (23902, 'skia-buildbot', 'Go', 158)
# (23903, 'perfetto', 'C++', 5022)
# (23904, 'XNNPACK', 'C', 2181)
# (23905, 'or-tools', 'C++', 12716)
# (23906, 'crubit', 'C++', 924)
# (23907, 'koladata', 'C++', 27)
# (23908, 'heir', 'C++', 610)
# (23909, 'wasefire', 'Rust', 129)
# (23910, 'dwh-migration-tools', 'Java', 54)
# (23911, 'dive', 'C++', 17)
# (23912, 'skia-buildbot', 'Go', 158)
# (23913, 'perfetto', 'C++', 5022)
# (23914, 'XNNPACK', 'C', 2181)
# (23915, 'or-tools', 'C++', 12716)
# (23916, 'crubit', 'C++', 924)
# (23917, 'koladata', 'C++', 27)
# (23918, 'heir', 'C++', 610)
# (23919, 'wasefire', 'Rust', 129)
# (23920, 'dwh-migration-tools', 'Java', 54)
# (23921, 'dive', 'C++', 17)
# (23922, 'skia-buildbot', 'Go', 158)
# (23923, 'perfetto', 'C++', 5022)
# (23924, 'XNNPACK', 'C', 2181)
# (23925, 'or-tools', 'C++', 12716)
# (23926, 'crubit', 'C++', 924)
# (23927, 'koladata', 'C++', 27)
# (23928, 'heir', 'C++', 610)
# (23929, 'wasefire', 'Rust', 129)
# (23930, 'dwh-migration-tools', 'Java', 54)
# (23931, 'dive', 'C++', 17)
# (23932, 'skia-buildbot', 'Go', 158)
# (23933, 'perfetto', 'C++', 5022)
# (23934, 'XNNPACK', 'C', 2181)
# (23935, 'or-tools', 'C++', 12716)
# (23936, 'crubit', 'C++', 924)
# (23937, 'koladata', 'C++', 27)
# (23938, 'heir', 'C++', 610)
# (23939, 'wasefire', 'Rust', 129)
# (23940, 'dwh-migration-tools', 'Java', 54)
# (23941, 'dive', 'C++', 17)
# (23942, 'skia-buildbot', 'Go', 158)
# (23943, 'perfetto', 'C++', 5022)
# (23944, 'XNNPACK', 'C', 2181)
# (23945, 'or-tools', 'C++', 12716)
# (23946, 'crubit', 'C++', 924)
# (23947, 'koladata', 'C++', 27)
# (23948, 'heir', 'C++', 610)
# (23949, 'wasefire', 'Rust', 129)
# (23950, 'dwh-migration-tools', 'Java', 54)
# (23951, 'dive', 'C++', 17)
# (23952, 'skia-buildbot', 'Go', 158)
# (23953, 'perfetto', 'C++', 5022)
# (23954, 'XNNPACK', 'C', 2181)
# (23955, 'or-tools', 'C++', 12716)
# (23956, 'crubit', 'C++', 924)
# (23957, 'koladata', 'C++', 27)
# (23958, 'heir', 'C++', 610)
# (23959, 'wasefire', 'Rust', 129)
# (23960, 'dwh-migration-tools', 'Java', 54)
# (23961, 'dive', 'C++', 17)
# (23962, 'skia-buildbot', 'Go', 158)
# (23963, 'perfetto', 'C++', 5022)
# (23964, 'XNNPACK', 'C', 2181)
# (23965, 'or-tools', 'C++', 12716)
# (23966, 'crubit', 'C++', 924)
# (23967, 'koladata', 'C++', 27)
# (23968, 'heir', 'C++', 610)
# (23969, 'wasefire', 'Rust', 129)
# (23970, 'dwh-migration-tools', 'Java', 54)
# (23971, 'dive', 'C++', 17)
# (23972, 'skia-buildbot', 'Go', 158)
# (23973, 'perfetto', 'C++', 5022)
# (23974, 'XNNPACK', 'C', 2181)
# (23975, 'or-tools', 'C++', 12716)
# (23976, 'crubit', 'C++', 924)
# (23977, 'koladata', 'C++', 27)
# (23978, 'heir', 'C++', 610)
# (23979, 'wasefire', 'Rust', 129)
# (23980, 'dwh-migration-tools', 'Java', 54)
# (23981, 'dive', 'C++', 17)
# (23982, 'skia-buildbot', 'Go', 158)
# (23983, 'perfetto', 'C++', 5022)
# (23984, 'XNNPACK', 'C', 2181)
# (23985, 'or-tools', 'C++', 12716)
# (23986, 'crubit', 'C++', 924)
# (23987, 'koladata', 'C++', 27)
# (23988, 'heir', 'C++', 610)
# (23989, 'wasefire', 'Rust', 129)
# (23990, 'dwh-migration-tools', 'Java', 54)
# (23991, 'dive', 'C++', 17)
# (23992, 'skia-buildbot', 'Go', 158)
# (23993, 'perfetto', 'C++', 5022)
# (23994, 'XNNPACK', 'C', 2181)
# (23995, 'or-tools', 'C++', 12716)
# (23996, 'crubit', 'C++', 924)
# (23997, 'koladata', 'C++', 27)
# (23998, 'heir', 'C++', 610)
# (23999, 'wasefire', 'Rust', 129)
# (24000, 'dwh-migration-tools', 'Java', 54)
# (24001, 'dive', 'C++', 17)
# (24002, 'skia-buildbot', 'Go', 158)
# (24003, 'perfetto', 'C++', 5022)
# (24004, 'XNNPACK', 'C', 2181)
# (24005, 'or-tools', 'C++', 12716)
# (24006, 'crubit', 'C++', 924)
# (24007, 'koladata', 'C++', 27)
# (24008, 'heir', 'C++', 610)
# (24009, 'wasefire', 'Rust', 129)
# (24010, 'dwh-migration-tools', 'Java', 54)
# (24011, 'dive', 'C++', 17)
# (24012, 'skia-buildbot', 'Go', 158)
# (24013, 'perfetto', 'C++', 5022)
# (24014, 'XNNPACK', 'C', 2181)
# (24015, 'or-tools', 'C++', 12716)
# (24016, 'crubit', 'C++', 924)
# (24017, 'koladata', 'C++', 27)
# (24018, 'heir', 'C++', 610)
# (24019, 'wasefire', 'Rust', 129)
# (24020, 'dwh-migration-tools', 'Java', 54)
# (24021, 'dive', 'C++', 17)
# (24022, 'skia-buildbot', 'Go', 158)
# (24023, 'perfetto', 'C++', 5022)
# (24024, 'XNNPACK', 'C', 2181)
# (24025, 'or-tools', 'C++', 12716)
# (24026, 'crubit', 'C++', 924)
# (24027, 'koladata', 'C++', 27)
# (24028, 'heir', 'C++', 610)
# (24029, 'wasefire', 'Rust', 129)
# (24030, 'dwh-migration-tools', 'Java', 54)
# (24031, 'dive', 'C++', 17)
# (24032, 'skia-buildbot', 'Go', 158)
# (24033, 'perfetto', 'C++', 5022)
# (24034, 'XNNPACK', 'C', 2181)
# (24035, 'or-tools', 'C++', 12716)
# (24036, 'crubit', 'C++', 924)
# (24037, 'koladata', 'C++', 27)
# (24038, 'heir', 'C++', 610)
# (24039, 'wasefire', 'Rust', 129)
# (24040, 'dwh-migration-tools', 'Java', 54)
# (24041, 'dive', 'C++', 17)
# (24042, 'skia-buildbot', 'Go', 158)
# (24043, 'perfetto', 'C++', 5022)
# (24044, 'XNNPACK', 'C', 2181)
# (24045, 'or-tools', 'C++', 12716)
# (24046, 'crubit', 'C++', 924)
# (24047, 'koladata', 'C++', 27)
# (24048, 'heir', 'C++', 610)
# (24049, 'wasefire', 'Rust', 129)
# (24050, 'dwh-migration-tools', 'Java', 54)
# (24051, 'dive', 'C++', 17)
# (24052, 'skia-buildbot', 'Go', 158)
# (24053, 'perfetto', 'C++', 5022)
# (24054, 'XNNPACK', 'C', 2181)
# (24055, 'or-tools', 'C++', 12716)
# (24056, 'crubit', 'C++', 924)
# (24057, 'koladata', 'C++', 27)
# (24058, 'heir', 'C++', 610)
# (24059, 'wasefire', 'Rust', 129)
# (24060, 'dwh-migration-tools', 'Java', 54)
# (24061, 'dive', 'C++', 17)
# (24062, 'skia-buildbot', 'Go', 158)
# (24063, 'perfetto', 'C++', 5022)
# (24064, 'XNNPACK', 'C', 2181)
# (24065, 'or-tools', 'C++', 12716)
# (24066, 'crubit', 'C++', 924)
# (24067, 'koladata', 'C++', 27)
# (24068, 'heir', 'C++', 610)
# (24069, 'wasefire', 'Rust', 129)
# (24070, 'dwh-migration-tools', 'Java', 54)
# (24071, 'dive', 'C++', 17)
# (24072, 'skia-buildbot', 'Go', 158)
# (24073, 'perfetto', 'C++', 5022)
# (24074, 'XNNPACK', 'C', 2181)
# (24075, 'or-tools', 'C++', 12716)
# (24076, 'crubit', 'C++', 924)
# (24077, 'koladata', 'C++', 27)
# (24078, 'heir', 'C++', 610)
# (24079, 'wasefire', 'Rust', 129)
# (24080, 'dwh-migration-tools', 'Java', 54)
# (24081, 'dive', 'C++', 17)
# (24082, 'skia-buildbot', 'Go', 158)
# (24083, 'perfetto', 'C++', 5022)
# (24084, 'XNNPACK', 'C', 2181)
# (24085, 'or-tools', 'C++', 12716)
# (24086, 'crubit', 'C++', 924)
# (24087, 'koladata', 'C++', 27)
# (24088, 'heir', 'C++', 610)
# (24089, 'wasefire', 'Rust', 129)
# (24090, 'dwh-migration-tools', 'Java', 54)
# (24091, 'dive', 'C++', 17)
# (24092, 'skia-buildbot', 'Go', 158)
# (24093, 'perfetto', 'C++', 5022)
# (24094, 'XNNPACK', 'C', 2181)
# (24095, 'or-tools', 'C++', 12716)
# (24096, 'crubit', 'C++', 924)
# (24097, 'koladata', 'C++', 27)
# (24098, 'heir', 'C++', 610)
# (24099, 'wasefire', 'Rust', 129)
# (24100, 'dwh-migration-tools', 'Java', 54)
# (24101, 'dive', 'C++', 17)
# (24102, 'skia-buildbot', 'Go', 158)
# (24103, 'perfetto', 'C++', 5022)
# (24104, 'XNNPACK', 'C', 2181)
# (24105, 'or-tools', 'C++', 12716)
# (24106, 'crubit', 'C++', 924)
# (24107, 'koladata', 'C++', 27)
# (24108, 'heir', 'C++', 610)
# (24109, 'wasefire', 'Rust', 129)
# (24110, 'dwh-migration-tools', 'Java', 54)
# (24111, 'dive', 'C++', 17)
# (24112, 'skia-buildbot', 'Go', 158)
# (24113, 'perfetto', 'C++', 5022)
# (24114, 'XNNPACK', 'C', 2181)
# (24115, 'or-tools', 'C++', 12716)
# (24116, 'crubit', 'C++', 924)
# (24117, 'koladata', 'C++', 27)
# (24118, 'heir', 'C++', 610)
# (24119, 'wasefire', 'Rust', 129)
# (24120, 'dwh-migration-tools', 'Java', 54)
# (24121, 'dive', 'C++', 17)
# (24122, 'skia-buildbot', 'Go', 158)
# (24123, 'perfetto', 'C++', 5022)
# (24124, 'XNNPACK', 'C', 2181)
# (24125, 'or-tools', 'C++', 12716)
# (24126, 'crubit', 'C++', 924)
# (24127, 'koladata', 'C++', 27)
# (24128, 'heir', 'C++', 610)
# (24129, 'wasefire', 'Rust', 129)
# (24130, 'dwh-migration-tools', 'Java', 54)
# (24131, 'dive', 'C++', 17)
# (24132, 'skia-buildbot', 'Go', 158)
# (24133, 'perfetto', 'C++', 5022)
# (24134, 'XNNPACK', 'C', 2181)
# (24135, 'or-tools', 'C++', 12716)
# (24136, 'crubit', 'C++', 924)
# (24137, 'koladata', 'C++', 27)
# (24138, 'heir', 'C++', 610)
# (24139, 'wasefire', 'Rust', 129)
# (24140, 'dwh-migration-tools', 'Java', 54)
# (24141, 'dive', 'C++', 17)
# (24142, 'skia-buildbot', 'Go', 158)
# (24143, 'perfetto', 'C++', 5022)
# (24144, 'XNNPACK', 'C', 2181)
# (24145, 'or-tools', 'C++', 12716)
# (24146, 'crubit', 'C++', 924)
# (24147, 'koladata', 'C++', 27)
# (24148, 'heir', 'C++', 610)
# (24149, 'wasefire', 'Rust', 129)
# (24150, 'dwh-migration-tools', 'Java', 54)
# (24151, 'dive', 'C++', 17)
# (24152, 'skia-buildbot', 'Go', 158)
# (24153, 'perfetto', 'C++', 5022)
# (24154, 'XNNPACK', 'C', 2181)
# (24155, 'or-tools', 'C++', 12716)
# (24156, 'crubit', 'C++', 924)
# (24157, 'koladata', 'C++', 27)
# (24158, 'heir', 'C++', 610)
# (24159, 'wasefire', 'Rust', 129)
# (24160, 'dwh-migration-tools', 'Java', 54)
# (24161, 'dive', 'C++', 17)
# (24162, 'skia-buildbot', 'Go', 158)
# (24163, 'perfetto', 'C++', 5022)
# (24164, 'XNNPACK', 'C', 2181)
# (24165, 'or-tools', 'C++', 12716)
# (24166, 'crubit', 'C++', 924)
# (24167, 'koladata', 'C++', 27)
# (24168, 'heir', 'C++', 610)
# (24169, 'wasefire', 'Rust', 129)
# (24170, 'dwh-migration-tools', 'Java', 54)
# (24171, 'dive', 'C++', 17)
# (24172, 'skia-buildbot', 'Go', 158)
# (24173, 'perfetto', 'C++', 5022)
# (24174, 'XNNPACK', 'C', 2181)
# (24175, 'or-tools', 'C++', 12716)
# (24176, 'crubit', 'C++', 924)
# (24177, 'koladata', 'C++', 27)
# (24178, 'heir', 'C++', 610)
# (24179, 'wasefire', 'Rust', 129)
# (24180, 'dwh-migration-tools', 'Java', 54)
# (24181, 'dive', 'C++', 17)
# (24182, 'skia-buildbot', 'Go', 158)
# (24183, 'perfetto', 'C++', 5022)
# (24184, 'XNNPACK', 'C', 2181)
# (24185, 'or-tools', 'C++', 12716)
# (24186, 'crubit', 'C++', 924)
# (24187, 'koladata', 'C++', 27)
# (24188, 'heir', 'C++', 610)
# (24189, 'wasefire', 'Rust', 129)
# (24190, 'dwh-migration-tools', 'Java', 54)
# (24191, 'dive', 'C++', 17)
# (24192, 'skia-buildbot', 'Go', 158)
# (24193, 'perfetto', 'C++', 5022)
# (24194, 'XNNPACK', 'C', 2181)
# (24195, 'or-tools', 'C++', 12716)
# (24196, 'crubit', 'C++', 924)
# (24197, 'koladata', 'C++', 27)
# (24198, 'heir', 'C++', 610)
# (24199, 'wasefire', 'Rust', 129)
# (24200, 'dwh-migration-tools', 'Java', 54)
# (24201, 'dive', 'C++', 17)
# (24202, 'skia-buildbot', 'Go', 158)
# (24203, 'perfetto', 'C++', 5022)
# (24204, 'XNNPACK', 'C', 2181)
# (24205, 'or-tools', 'C++', 12716)
# (24206, 'crubit', 'C++', 924)
# (24207, 'koladata', 'C++', 27)
# (24208, 'heir', 'C++', 610)
# (24209, 'wasefire', 'Rust', 129)
# (24210, 'dwh-migration-tools', 'Java', 54)
# (24211, 'dive', 'C++', 17)
# (24212, 'skia-buildbot', 'Go', 158)
# (24213, 'perfetto', 'C++', 5022)
# (24214, 'XNNPACK', 'C', 2181)
# (24215, 'or-tools', 'C++', 12716)
# (24216, 'crubit', 'C++', 924)
# (24217, 'koladata', 'C++', 27)
# (24218, 'heir', 'C++', 610)
# (24219, 'wasefire', 'Rust', 129)
# (24220, 'dwh-migration-tools', 'Java', 54)
# (24221, 'dive', 'C++', 17)
# (24222, 'skia-buildbot', 'Go', 158)
# (24223, 'perfetto', 'C++', 5022)
# (24224, 'XNNPACK', 'C', 2181)
# (24225, 'or-tools', 'C++', 12716)
# (24226, 'crubit', 'C++', 924)
# (24227, 'koladata', 'C++', 27)
# (24228, 'heir', 'C++', 610)
# (24229, 'wasefire', 'Rust', 129)
# (24230, 'dwh-migration-tools', 'Java', 54)
# (24231, 'dive', 'C++', 17)
# (24232, 'skia-buildbot', 'Go', 158)
# (24233, 'perfetto', 'C++', 5022)
# (24234, 'XNNPACK', 'C', 2181)
# (24235, 'or-tools', 'C++', 12716)
# (24236, 'crubit', 'C++', 924)
# (24237, 'koladata', 'C++', 27)
# (24238, 'heir', 'C++', 610)
# (24239, 'wasefire', 'Rust', 129)
# (24240, 'dwh-migration-tools', 'Java', 54)
# (24241, 'dive', 'C++', 17)
# (24242, 'skia-buildbot', 'Go', 158)
# (24243, 'perfetto', 'C++', 5022)
# (24244, 'XNNPACK', 'C', 2181)
# (24245, 'or-tools', 'C++', 12716)
# (24246, 'crubit', 'C++', 924)
# (24247, 'koladata', 'C++', 27)
# (24248, 'heir', 'C++', 610)
# (24249, 'wasefire', 'Rust', 129)
# (24250, 'dwh-migration-tools', 'Java', 54)
# (24251, 'dive', 'C++', 17)
# (24252, 'skia-buildbot', 'Go', 158)
# (24253, 'perfetto', 'C++', 5022)
# (24254, 'XNNPACK', 'C', 2181)
# (24255, 'or-tools', 'C++', 12716)
# (24256, 'crubit', 'C++', 924)
# (24257, 'koladata', 'C++', 27)
# (24258, 'heir', 'C++', 610)
# (24259, 'wasefire', 'Rust', 129)
# (24260, 'dwh-migration-tools', 'Java', 54)
# (24261, 'dive', 'C++', 17)
# (24262, 'skia-buildbot', 'Go', 158)
# (24263, 'perfetto', 'C++', 5022)
# (24264, 'XNNPACK', 'C', 2181)
# (24265, 'or-tools', 'C++', 12716)
# (24266, 'crubit', 'C++', 924)
# (24267, 'koladata', 'C++', 27)
# (24268, 'heir', 'C++', 610)
# (24269, 'wasefire', 'Rust', 129)
# (24270, 'dwh-migration-tools', 'Java', 54)
# (24271, 'dive', 'C++', 17)
# (24272, 'skia-buildbot', 'Go', 158)
# (24273, 'perfetto', 'C++', 5022)
# (24274, 'XNNPACK', 'C', 2181)
# (24275, 'or-tools', 'C++', 12716)
# (24276, 'crubit', 'C++', 924)
# (24277, 'koladata', 'C++', 27)
# (24278, 'heir', 'C++', 610)
# (24279, 'wasefire', 'Rust', 129)
# (24280, 'dwh-migration-tools', 'Java', 54)

# %% [markdown]
# ## 保存データの中身を確認

# %%
cur.execute("SELECT id, name, language, stars FROM repos LIMIT 10")
for row in cur.fetchall():
    print(row)
# Out:
# (1, 'perfetto', 'C++', 5022)
# (2, 'adk-java', 'Java', 973)
# (3, 'ksp', 'Kotlin', 3307)
# (4, 'XNNPACK', 'C', 2181)
# (5, 'koladata', 'C++', 27)
# (6, 'skia-buildbot', 'Go', 158)
# (7, 'merchant-api-samples', 'Java', 10)
# (8, 'xls', 'C++', 1375)
# (9, 'clusterfuzz', 'Python', 5491)
# (10, 'skia', 'C++', 10275)
